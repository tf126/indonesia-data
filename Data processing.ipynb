# %%
# https://kodepos.nomor.net/_kodepos.php?_i=provinsi-kodepos
# document.body.onselectstart = function() {return true;};

# %%
import re
import json

# %%
def flatten(l):
    if not isinstance(l, list):
        return [l]
    out = []
    for v in l:
        out += flatten(v)
    return out

# %%
from collections import UserDict
class Map(UserDict):
    def __init__(self, kv_iter):
        d = {}
        if isinstance(kv_iter, dict) or isinstance(kv_iter, UserDict):
            kv_iter = kv_iter.items()
        for k, v in kv_iter:
            if k not in d:
                d[k] = []
            if not isinstance(v, list):
                v = [v]
            d[k] += v
        super().__init__(d)
    def mapk(self, transform_or_dict):
        out = {}
        if isinstance(transform_or_dict, dict) or isinstance(transform_or_dict, UserDict):
            transform = lambda k: transform_or_dict[k]
        else:
            transform = transform_or_dict
        for k, v in self.data.items():
            nks = transform(k)
            if not isinstance(nks, list):
                nks = [nks]
            for nk in nks:
                if nk not in out:
                    out[nk] = []
                if not isinstance(v, list):
                    v = [v]
                out[nk] += v
        for k, v in out.items():
            out[k] = list(set(flatten(v)))
        return Map(out.items())
    def mapv(self, transform_or_dict):
        out = {}
        if isinstance(transform_or_dict, dict) or isinstance(transform_or_dict, UserDict):
            transform = lambda k: transform_or_dict[k]
        else:
            transform = transform_or_dict
        for k, vs in self.data.items():
            for v in vs:
                nvs = transform(v)
                if not isinstance(nvs, list):
                    nvs = [nvs]
                if k not in out:
                    out[k] = []
                out[k] += nvs
        for k, v in out.items():
            out[k] = list(set(flatten(v)))
        return Map(out.items())
    def json(self):
        return json.dumps(self.data)
    def bj(self):
        failed = False
        for k, v in self.data.items():
            if len(v) != 1:
                print({k: v})
                failed = True
        return not failed
        
    def reverse(self):
        out = {}
        for k, vs in self.data.items():
            for v in vs:
                if v not in out:
                    out[v] = []
                out[v].append(k)
        for k, v in out.items():
            out[k] = list(set(flatten(v)))
        return Map(out.items())
    def __contains__(self, key):
        if isinstance(key, list):
            keys = key
        elif isinstance(key, dict) or isinstance(key, UserDict):
            keys = key.keys()
        else:
            keys = [key]
        return all([key in self.data for key in keys])
    def __iadd__(self, other):
        other = Map(other)
        for k, vs in other.items():
            if k not in self.data:
                self.data[k] = []
            self.data[k] += vs
        for k, v in self.data.items():
            self.data[k] = list(set(flatten(v)))
        return self
    def __radd__(self, other):
        out = Map(other)
        out += self
        return out
    def __add__(self, other):
        return self.__radd__(other)
    def asdict(self):
        if not self.bj():
            raise RuntimeError('map is not bijective')
        return {k: vs[0] for k, vs in self.data.items()}

# %%
c2p = [row.split('\t') for row in open('raw_c2p.txt', 'r').read().strip().split('\n')]

# %%
d2c = [row.split('\t') for row in open('raw_d2c.txt', 'r').read().strip().split('\n')]

# %%
mc2p = Map(c2p)
mc2p
# Out:
# {'Yogyakarta': ['DI Yogyakarta'], 'Yalimo': ['Papua'], 'Yahukimo': ['Papua'], 'Wonosobo': ['Jawa Tengah'], 'Wonogiri': ['Jawa Tengah'], 'Way Kanan': ['Lampung'], 'Waropen': ['Papua'], 'Wakatobi': ['Sulawesi Tenggara'], 'Wajo': ['Sulawesi Selatan'], 'Tulungagung': ['Jawa Timur'], 'Tulang Bawang Barat': ['Lampung'], 'Tulang Bawang': ['Lampung'], 'Tuban': ['Jawa Timur'], 'Tual': ['Maluku'], 'Trenggalek': ['Jawa Timur'], 'Toraja Utara': ['Sulawesi Selatan'], 'Tomohon': ['Sulawesi Utara'], 'Tolikara': ['Papua'], 'Toli-Toli': ['Sulawesi Tengah'], 'Tojo Una-Una': ['Sulawesi Tengah'], 'Toba Samosir': ['Sumatera Utara'], 'Timor Tengah Utara': ['Nusa Tenggara Timur (NTT)'], 'Timor Tengah Selatan': ['Nusa Tenggara Timur (NTT)'], 'Tidore Kepulauan': ['Maluku Utara'], 'Ternate': ['Maluku Utara'], 'Temanggung': ['Jawa Tengah'], 'Teluk Wondama': ['Papua Barat'], 'Teluk Bintuni': ['Papua Barat'], 'Tegal': ['Jawa Tengah', 'Jawa Tengah'], 'Tebo': ['Jambi'], 'Tebing Tinggi': ['Sumatera Utara'], 'Tasikmalaya': ['Jawa Barat', 'Jawa Barat'], 'Tarakan': ['Kalimantan Utara'], 'Tapin': ['Kalimantan Selatan'], 'Tapanuli Utara': ['Sumatera Utara'], 'Tapanuli Tengah': ['Sumatera Utara'], 'Tapanuli Selatan': ['Sumatera Utara'], 'Tanjung Pinang': ['Kepulauan Riau'], 'Tanjung Jabung Timur': ['Jambi'], 'Tanjung Jabung Barat': ['Jambi'], 'Tanjung Balai': ['Sumatera Utara'], 'Tanggamus': ['Lampung'], 'Tangerang Selatan': ['Banten'], 'Tangerang': ['Banten', 'Banten'], 'Tanah Laut': ['Kalimantan Selatan'], 'Tanah Datar': ['Sumatera Barat'], 'Tanah Bumbu': ['Kalimantan Selatan'], 'Tana Toraja': ['Sulawesi Selatan'], 'Tana Tidung': ['Kalimantan Utara'], 'Tambrauw': ['Papua Barat'], 'Takalar': ['Sulawesi Selatan'], 'Tabanan': ['Bali'], 'Tabalong': ['Kalimantan Selatan'], 'Surakarta': ['Jawa Tengah'], 'Surabaya': ['Jawa Timur'], 'Supiori': ['Papua'], 'Sungaipenuh': ['Jambi'], 'Sumenep': ['Jawa Timur'], 'Sumedang': ['Jawa Barat'], 'Sumbawa Barat': ['Nusa Tenggara Barat (NTB)'], 'Sumbawa': ['Nusa Tenggara Barat (NTB)'], 'Sumba Timur': ['Nusa Tenggara Timur (NTT)'], 'Sumba Tengah': ['Nusa Tenggara Timur (NTT)'], 'Sumba Barat Daya': ['Nusa Tenggara Timur (NTT)'], 'Sumba Barat': ['Nusa Tenggara Timur (NTT)'], 'Sukoharjo': ['Jawa Tengah'], 'Sukamara': ['Kalimantan Tengah'], 'Sukabumi': ['Jawa Barat', 'Jawa Barat'], 'Subulussalam': ['Aceh (NAD)'], 'Subang': ['Jawa Barat'], 'Sragen': ['Jawa Tengah'], 'Sorong Selatan': ['Papua Barat'], 'Sorong': ['Papua Barat', 'Papua Barat'], 'Soppeng': ['Sulawesi Selatan'], 'Solok Selatan': ['Sumatera Barat'], 'Solok': ['Sumatera Barat', 'Sumatera Barat'], 'Sleman': ['DI Yogyakarta'], 'Situbondo': ['Jawa Timur'], 'Sintang': ['Kalimantan Barat'], 'Sinjai': ['Sulawesi Selatan'], 'Singkawang': ['Kalimantan Barat'], 'Simeulue': ['Aceh (NAD)'], 'Simalungun': ['Sumatera Utara'], 'Sikka': ['Nusa Tenggara Timur (NTT)'], 'Sijunjung': ['Sumatera Barat'], 'Sigi': ['Sulawesi Tengah'], 'Sidoarjo': ['Jawa Timur'], 'Sidenreng Rappang': ['Sulawesi Selatan'], 'Sibolga': ['Sumatera Utara'], 'Siak': ['Riau'], 'Seruyan': ['Kalimantan Tengah'], 'Serdang Bedagai': ['Sumatera Utara'], 'Serang': ['Banten', 'Banten'], 'Seram Bagian Timur': ['Maluku'], 'Seram Bagian Barat': ['Maluku'], 'Semarang': ['Jawa Tengah', 'Jawa Tengah'], 'Seluma': ['Bengkulu'], 'Sekadau': ['Kalimantan Barat'], 'Sawah Lunto': ['Sumatera Barat'], 'Sarolangun': ['Jambi'], 'Sarmi': ['Papua'], 'Sanggau': ['Kalimantan Barat'], 'Sampang': ['Jawa Timur'], 'Samosir': ['Sumatera Utara'], 'Sambas': ['Kalimantan Barat'], 'Samarinda': ['Kalimantan Timur'], 'Salatiga': ['Jawa Tengah'], 'Sabu Raijua': ['Nusa Tenggara Timur (NTT)'], 'Sabang': ['Aceh (NAD)'], 'Rote Ndao': ['Nusa Tenggara Timur (NTT)'], 'Rokan Hulu': ['Riau'], 'Rokan Hilir': ['Riau'], 'Rembang': ['Jawa Tengah'], 'Rejang Lebong': ['Bengkulu'], 'Raja Ampat': ['Papua Barat'], 'Purworejo': ['Jawa Tengah'], 'Purwakarta': ['Jawa Barat'], 'Purbalingga': ['Jawa Tengah'], 'Puncak Jaya': ['Papua'], 'Puncak': ['Papua'], 'Pulau Taliabu': ['Maluku Utara' ...

# %%
def stransform(k):
    o1 = k.strip().lower()
    o2 = re.sub(r'[^a-z0-9]', '', o1)
    return o2

# %%
# transform names, handles cases like Name ( AlternateName / AlternateName2 )
def gtransform(k):
    o1 = k.strip().lower()
    keys = re.split(r'\(([^)]*)\)', o1)
    if len(keys) > 1:
        return flatten([gtransform(key) for key in keys if len(key) > 0])
    keys = o1.split('/')
    if len(keys) > 1:
        return flatten([gtransform(key) for key in keys if len(key) > 0])
    o2 = re.sub(r'[^a-z0-9]', '', o1)
    return o2

# %%
[[k, stransform(k)] for k, v in c2p]
# Out:
# [['Yogyakarta', 'yogyakarta'],
#  ['Yalimo', 'yalimo'],
#  ['Yahukimo', 'yahukimo'],
#  ['Wonosobo', 'wonosobo'],
#  ['Wonogiri', 'wonogiri'],
#  ['Way Kanan', 'waykanan'],
#  ['Waropen', 'waropen'],
#  ['Wakatobi', 'wakatobi'],
#  ['Wajo', 'wajo'],
#  ['Tulungagung', 'tulungagung'],
#  ['Tulang Bawang Barat', 'tulangbawangbarat'],
#  ['Tulang Bawang', 'tulangbawang'],
#  ['Tuban', 'tuban'],
#  ['Tual', 'tual'],
#  ['Trenggalek', 'trenggalek'],
#  ['Toraja Utara', 'torajautara'],
#  ['Tomohon', 'tomohon'],
#  ['Tolikara', 'tolikara'],
#  ['Toli-Toli', 'tolitoli'],
#  ['Tojo Una-Una', 'tojounauna'],
#  ['Toba Samosir', 'tobasamosir'],
#  ['Timor Tengah Utara', 'timortengahutara'],
#  ['Timor Tengah Selatan', 'timortengahselatan'],
#  ['Tidore Kepulauan', 'tidorekepulauan'],
#  ['Ternate', 'ternate'],
#  ['Temanggung', 'temanggung'],
#  ['Teluk Wondama', 'telukwondama'],
#  ['Teluk Bintuni', 'telukbintuni'],
#  ['Tegal', 'tegal'],
#  ['Tegal', 'tegal'],
#  ['Tebo', 'tebo'],
#  ['Tebing Tinggi', 'tebingtinggi'],
#  ['Tasikmalaya', 'tasikmalaya'],
#  ['Tasikmalaya', 'tasikmalaya'],
#  ['Tarakan', 'tarakan'],
#  ['Tapin', 'tapin'],
#  ['Tapanuli Utara', 'tapanuliutara'],
#  ['Tapanuli Tengah', 'tapanulitengah'],
#  ['Tapanuli Selatan', 'tapanuliselatan'],
#  ['Tanjung Pinang', 'tanjungpinang'],
#  ['Tanjung Jabung Timur', 'tanjungjabungtimur'],
#  ['Tanjung Jabung Barat', 'tanjungjabungbarat'],
#  ['Tanjung Balai', 'tanjungbalai'],
#  ['Tanggamus', 'tanggamus'],
#  ['Tangerang Selatan', 'tangerangselatan'],
#  ['Tangerang', 'tangerang'],
#  ['Tangerang', 'tangerang'],
#  ['Tanah Laut', 'tanahlaut'],
#  ['Tanah Datar', 'tanahdatar'],
#  ['Tanah Bumbu', 'tanahbumbu'],
#  ['Tana Toraja', 'tanatoraja'],
#  ['Tana Tidung', 'tanatidung'],
#  ['Tambrauw', 'tambrauw'],
#  ['Takalar', 'takalar'],
#  ['Tabanan', 'tabanan'],
#  ['Tabalong', 'tabalong'],
#  ['Surakarta', 'surakarta'],
#  ['Surabaya', 'surabaya'],
#  ['Supiori', 'supiori'],
#  ['Sungaipenuh', 'sungaipenuh'],
#  ['Sumenep', 'sumenep'],
#  ['Sumedang', 'sumedang'],
#  ['Sumbawa Barat', 'sumbawabarat'],
#  ['Sumbawa', 'sumbawa'],
#  ['Sumba Timur', 'sumbatimur'],
#  ['Sumba Tengah', 'sumbatengah'],
#  ['Sumba Barat Daya', 'sumbabaratdaya'],
#  ['Sumba Barat', 'sumbabarat'],
#  ['Sukoharjo', 'sukoharjo'],
#  ['Sukamara', 'sukamara'],
#  ['Sukabumi', 'sukabumi'],
#  ['Sukabumi', 'sukabumi'],
#  ['Subulussalam', 'subulussalam'],
#  ['Subang', 'subang'],
#  ['Sragen', 'sragen'],
#  ['Sorong Selatan', 'sorongselatan'],
#  ['Sorong', 'sorong'],
#  ['Sorong', 'sorong'],
#  ['Soppeng', 'soppeng'],
#  ['Solok Selatan', 'solokselatan'],
#  ['Solok', 'solok'],
#  ['Solok', 'solok'],
#  ['Sleman', 'sleman'],
#  ['Situbondo', 'situbondo'],
#  ['Sintang', 'sintang'],
#  ['Sinjai', 'sinjai'],
#  ['Singkawang', 'singkawang'],
#  ['Simeulue', 'simeulue'],
#  ['Simalungun', 'simalungun'],
#  ['Sikka', 'sikka'],
#  ['Sijunjung', 'sijunjung'],
#  ['Sigi', 'sigi'],
#  ['Sidoarjo', 'sidoarjo'],
#  ['Sidenreng Rappang', 'sidenrengrappang'],
#  ['Sibolga', 'sibolga'],
#  ['Siak', 'siak'],
#  ['Seruyan', 'seruyan'],
#  ['Serdang Bedagai', 'serdangbedagai'],
#  ['Serang', 'serang'],
#  ['Serang', 'serang'],
#  ['Seram Bagian Timur', 'serambagiantimur'],
#  ['Seram Bagian Barat', 'serambagianbarat'],
#  ['Semarang', 'semarang'],
#  ['Semarang', 'semarang'],
#  ['Seluma', 'seluma'],
#  ['Sekadau', 'sekadau'],
#  ['Sawah Lunto', 'sawahlunto'],
#  ['Sarolangun', 'sarolangun'],
#  ['Sarmi', 'sarmi'],
#  ['Sanggau', 'sanggau'],
#  ['Sampang', 'sampang'],
#  ['Samosir', 'samosir'],
#  ['Sambas', 'sambas'],
#  ['Samarinda', 'samarinda'],
#  ['Salatiga', 'salatiga'],
#  ['Sabu Raijua', 'saburaijua'],
#  ['Sabang', 'sabang'],
#  ['Rote Ndao', 'rotendao'],
#  ['Rokan Hulu', 'rokanhulu'],
#  ['Rokan Hilir', 'rokanhilir'],
#  ['Rembang', 'rembang'],
#  ['Rejang Lebong', 'rejanglebong'],
#  ['Raja Ampat', 'rajaampat'],
#  ['Purworejo', 'purworejo'],
#  ['Purwakarta', 'purwakarta'],
#  ['Purbalingga', 'purbalingga'],
#  ['Puncak Jaya', 'puncakjaya'],
#  ['Puncak', 'puncak'],
#  ['Pulau Taliabu', 'pulautaliabu'],
#  ['Pulau Morotai', 'pulaumorotai'],
#  ['Pulang Pisau', 'pulangpisau'],
#  ['Probolinggo', 'probolinggo'],
#  ['Probolinggo', 'probolinggo'],
#  ['Pringsewu', 'pringsewu'],
#  ['Prabumulih', 'prabumulih'],
#  ['Poso', 'poso'],
#  ['Pontianak', 'pontianak'],
#  ['Ponorogo', 'ponorogo'],
#  ['Polewali Mandar', 'polewalimandar'],
#  ['Pohuwato', 'pohuwato'],
#  ['Pinrang', 'pinrang'],
#  ['Pidie Jaya', 'pidiejaya'],
#  ['Pidie', 'pidie'],
#  ['Pesisir Selatan', 'pesisirselatan'],
#  ['Pesisir Barat', 'pesisirbarat'],
#  ['Pesawaran', 'pesawaran'],
#  ['Penukal Abab Lematang Ilir', 'penukalabablematangilir'],
#  ['Penajam Paser Utara', 'penajampaserutara'],
#  ['Pematang Siantar', 'pematangsiantar'],
#  ['Pemalang', 'pemalang'],
#  ['Pelalawan', 'pelalawan'],
#  ['Pekanbaru', 'pekanbaru'],
#  ['Pekalongan', 'pekalongan'],
#  ['Pekalongan', 'pekalongan'],
#  ['Pegunungan Bintang', 'pegununganbintang'],
#  ['Pegunungan Arfak', 'pegununganarfak'],
#  ['Payakumbuh', 'payakumbuh'],
#  ['Pati', 'pati'],
#  ['Pasuruan', 'pasuruan'],
#  ['Pasuruan', 'pasuruan'],
#  ['Paser', 'paser'],
#  ['Pasangkayu (Mamuju Utara)', 'pasangkayumamujuutara'],
#  ['Pasaman Barat', 'pasamanbarat'],
#  ['Pasaman', 'pasaman'],
#  ['Parigi Moutong', 'parigimoutong'],
#  ['Pariaman', 'pariaman'],
#  ['Parepare', 'parepare'],
#  ['Paniai', 'paniai'],
#  ['Pangkal Pinang', 'pangkalpinang'],
#  ['Pangkajene Kepulauan', 'pangkajenekepulauan'],
#  ['Pangandaran', 'pangandaran'],
#  ['Pandeglang', 'pandeglang'],
#  ['Pamekasan', 'pamekasan'],
#  ['Palu', 'palu'],
#  ['Palopo', 'palopo'],
#  ['Palembang', 'palembang'],
#  ['Palangka Raya', 'palangkaraya'],
#  ['Pakpak Bharat', 'pakpakbharat'],
#  ['Pagar Alam', 'pagaralam'],
#  ['Padang Sidempuan', 'padangsidempuan'],
#  ['Padang Pariaman', 'padangpariaman'],
#  ['Padang Panjang', 'padangpanjang'],
#  ['Padang Lawas Utara', 'padanglawasutara'],
#  ['Padang Lawas', 'padanglawas'],
#  ['Padang', 'padang'],
#  ['Pacitan', 'pacitan'],
#  ['Ogan Komering Ulu Timur', 'ogankomeringulutimur'],
#  ['Ogan Komering Ulu Selatan', 'ogankomeringuluselatan'],
#  ['Ogan Komering Ulu', 'ogankomeringulu'],
#  ['Ogan Komering Ilir', 'ogankomeringilir'],
#  ['Ogan Ilir', 'oganilir'],
#  ['Nunukan', 'nunukan'],
#  ['Nias Utara', 'niasutara'],
#  ['Nias Selatan', 'niasselatan'],
#  ['Nias Barat', 'niasbarat'],
#  ['Nias', 'nias'],
#  ['Ngawi', 'ngawi'],
#  ['Nganjuk', 'nganjuk'],
#  ['Ngada', 'ngada'],
#  ['Nduga', 'nduga'],
#  ['Natuna', 'natuna'],
#  ['Nagekeo', 'nagekeo'],
#  ['Nagan Raya', 'naganraya'],
#  ['Nabire', 'nabire'],
#  ['Musi Rawas Utara', 'musirawasutara'],
#  ['Musi Rawas', 'musirawas'],
#  ['Musi Banyuasin', 'musibanyuasin'],
#  ['Murung Raya', 'murungraya'],
#  ['Muna Barat', 'munabarat'],
#  ['Muna', 'muna'],
#  ['Muko Muko', 'mukomuko'],
#  ['Muaro Jambi', 'muarojambi'],
#  ['Muara Enim', 'muaraenim'],
#  ['Morowali Utara', 'morowaliutara'],
#  ['Morowali', 'morowali'],
#  ['Mojokerto', 'mojokerto'],
#  ['Mojokerto', 'mojokerto'],
#  ['Minahasa Utara', 'minahasautara'],
#  ['Minahasa Tenggara', 'minahasatenggara'],
#  ['Minahasa Selatan', 'minahasaselatan'],
#  ['Minahasa', 'minahasa'],
#  ['Mimika', 'mimika'],
#  ['Metro', 'metro'],
#  ['Mesuji', 'mesuji'],
#  ['Merauke', 'merauke'],
#  ['Merangin', 'merangin'],
#  ['Mempawah', 'mempawah'],
#  ['Melawi', 'melawi'],
#  ['Medan', 'medan'],
#  ['Maybrat', 'maybrat'],
#  ['Mataram', 'mataram'],
#  ['Maros', 'maros'],
#  ['Mappi', 'mappi'],
#  ['Manokwari Selatan', 'manokwariselatan'],
#  ['Manokwari', 'manokwari'],
#  ['Manggarai Timur', 'manggaraitimur'],
#  ['Manggarai Barat', 'manggaraibarat'],
#  ['Manggarai', 'manggarai'],
#  ['Mandailing Natal', 'mandailingnatal'],
#  ['Manado', 'manado'],
#  ['Mamuju Tengah', 'mamujutengah'],
#  ['Mamuju', 'mamuju'],
#  ['Mamberamo Tengah', 'mamberamotengah'],
#  ['Mamberamo Raya', 'mamberamoraya'],
#  ['Mamasa', 'mamasa'],
#  ['Maluku Tenggara', 'malukutenggara'],
#  ['Maluku Tengah', 'malukutengah'],
#  ['Maluku Barat Daya', 'malukubaratdaya'],
#  ['Malinau', 'malinau'],
#  ['Malang', 'malang'],
#  ['Malang', 'malang'],
#  ['Malaka', 'malaka'],
#  ['Makassar', 'makassar'],
#  ['Majene', 'majene'],
#  ['Majalengka', 'majalengka'],
#  ['Mahakam Ulu', 'mahakamulu'],
#  ['Magetan', 'magetan'],
#  ['Magelang', 'magelang'],
#  ['Magelang', 'magelang'],
#  ['Madiun', 'madiun'],
#  ['Madiun', 'madiun'],
#  ['Luwu Utara', 'luwuutara'],
#  ['Luwu Timur', 'luwutimur'],
#  ['Luwu', 'luwu'],
#  ['Lumajang', 'lumajang'],
#  ['Lubuk Linggau', 'lubuklinggau'],
#  ['Lombok Utara', 'lombokutara'],
#  ['Lombok Timur', 'lomboktimur'],
#  ['Lombok Tengah', 'lomboktengah'],
#  ['Lombok Barat', 'lombokbarat'],
#  ['Lingga', 'lingga'],
#  ['Lima Puluh Kota', 'limapuluhkota'],
#  ['Lhokseumawe', 'lhokseumawe'],
#  ['Lembata', 'lembata'],
#  ['Lebong', 'lebong'],
#  ['Lebak', 'lebak'],
#  ['Lanny Jaya', 'lannyjaya'],
#  ['Langsa', 'langsa'],
#  ['Langkat', 'langkat'],
#  ['Landak', 'landak'],
#  ['Lampung Utara', 'lampungutara'],
#  ['Lampung Timur', 'lampungtimur'],
#  ['Lampung Tengah', 'lampungtengah'],
#  ['Lampung Selatan', 'lampungselatan'],
#  ['Lampung Barat', 'lampungbarat'],
#  ['Lamongan', 'lamongan'],
#  ['Lamandau', 'lamandau'],
#  ['Lahat', 'lahat'],
#  ['Labuhanbatu Utara', 'labuhanbatuutara'],
#  ['Labuhanbatu Selatan', 'labuhanbatuselatan'],
#  ['Labuhanbatu', 'labuhanbatu'],
#  ['Kutai Timur', 'kutaitimur'],
#  ['Kutai Kartanegara', 'kutaikartanegara'],
#  ['Kutai Barat', 'kutaibarat'],
#  ['Kupang', 'kupang'],
#  ['Kupang', 'kupang'],
#  ['Kuningan', 'kuningan'],
#  ['Kulon Progo', 'kulonprogo'],
#  ['Kudus', 'kudus'],
#  ['Kubu Raya', 'kuburaya'],
#  ['Kuantan Singingi', 'kuantansingingi'],
#  ['Kotawaringin Timur', 'kotawaringintimur'],
#  ['Kotawaringin Barat', 'kotawaringinbarat'],
#  ['Kotamobagu', 'kotamobagu'],
#  ['Kotabaru', 'kotabaru'],
#  ['Konawe Utara', 'konaweutara'],
#  ['Konawe Selatan', 'konaweselatan'],
#  ['Konawe Kepulauan', 'konawekepulauan'],
#  ['Konawe', 'konawe'],
#  ['Kolaka Utara', 'kolakautara'],
#  ['Kolaka Timur', 'kolakatimur'],
#  ['Kolaka', 'kolaka'],
#  ['Klungkung', 'klungkung'],
#  ['Klaten', 'klaten'],
#  ['Ketapang', 'ketapang'],
#  ['Kerinci', 'kerinci'],
#  ['Kepulauan Yapen', 'kepulauanyapen'],
#  ['Kepulauan Tanimbar (Maluku Tenggara Barat)',
#   'kepulauantanimbarmalukutenggarabarat'],
#  ['Kepulauan Talaud', 'kepulauantalaud'],
#  ['Kepulauan Sula', 'kepulauansula'],
#  ['Kepulauan Siau Tagulandang Biaro (Sitaro)',
#   'kepulauansiautagulandangbiarositaro'],
#  ['Kepulauan Seribu', 'kepulauanseribu'],
#  ['Kepulauan Selayar', 'kepulauanselayar'],
#  ['Kepulauan Sangihe', 'kepulauansangihe'],
#  ['Kepulauan Meranti', 'kepulauanmeranti'],
#  ['Kepulauan Mentawai', 'kepulauanmentawai'],
#  ['Kepulauan Aru', 'kepulauanaru'],
#  ['Kepulauan Anambas', 'kepulauananambas'],
#  ['Kepahiang', 'kepahiang'],
#  ['Kendari', 'kendari'],
#  ['Kendal', 'kendal'],
#  ['Keerom', 'keerom'],
#  ['Kediri', 'kediri'],
#  ['Kediri', 'kediri'],
#  ['Kebumen', 'kebumen'],
#  ['Kayong Utara', 'kayongutara'],
#  ['Kaur', 'kaur'],
#  ['Katingan', 'katingan'],
#  ['Karo', 'karo'],
#  ['Karimun', 'karimun'],
#  ['Karawang', 'karawang'],
#  ['Karangasem', 'karangasem'],
#  ['Karanganyar', 'karanganyar'],
#  ['Kapuas Hulu', 'kapuashulu'],
#  ['Kapuas', 'kapuas'],
#  ['Kampar', 'kampar'],
#  ['Kaimana', 'kaimana'],
#  ['Jombang', 'jombang'],
#  ['Jepara', 'jepara'],
#  ['Jeneponto', 'jeneponto'],
#  ['Jembrana', 'jembrana'],
#  ['Jember', 'jember'],
#  ['Jayawijaya', 'jayawijaya'],
#  ['Jayapura', 'jayapura'],
#  ['Jayapura', 'jayapura'],
#  ['Jambi', 'jambi'],
#  ['Jakarta Utara', 'jakartautara'],
#  ['Jakarta Timur', 'jakartatimur'],
#  ['Jakarta Selatan', 'jakartaselatan'],
#  ['Jakarta Pusat', 'jakartapusat'],
#  ['Jakarta Barat', 'jakartabarat'],
#  ['Intan Jaya', 'intanjaya'],
#  ['Indramayu', 'indramayu'],
#  ['Indragiri Hulu', 'indragirihulu'],
#  ['Indragiri Hilir', 'indragirihilir'],
#  ['Humbang Hasundutan', 'humbanghasundutan'],
#  ['Hulu Sungai Utara', 'hulusungaiutara'],
#  ['Hulu Sungai Tengah', 'hulusungaitengah'],
#  ['Hulu Sungai Selatan', 'hulusungaiselatan'],
#  ['Halmahera Utara', 'halmaherautara'],
#  ['Halmahera Timur', 'halmaheratimur'],
#  ['Halmahera Tengah', 'halmaheratengah'],
#  ['Halmahera Selatan', 'halmaheraselatan'],
#  ['Halmahera Barat', 'halmaherabarat'],
#  ['Gunungsitoli', 'gunungsitoli'],
#  ['Gunung Mas', 'gunungmas'],
#  ['Gunung Kidul', 'gunungkidul'],
#  ['Grobogan', 'grobogan'],
#  ['Gresik', 'gresik'],
#  ['Gowa', 'gowa'],
#  ['Gorontalo Utara', 'gorontaloutara'],
#  ['Gorontalo', 'gorontalo'],
#  ['Gorontalo', 'gorontalo'],
#  ['Gianyar', 'gianyar'],
#  ['Gayo Lues', 'gayolues'],
#  ['Garut', 'garut'],
#  ['Flores Timur', 'florestimur'],
#  ['Fakfak', 'fakfak'],
#  ['Enrekang', 'enrekang'],
#  ['Ende', 'ende'],
#  ['Empat Lawang', 'empatlawang'],
#  ['Dumai', 'dumai'],
#  ['Donggala', 'donggala'],
#  ['Dompu', 'dompu'],
#  ['Dogiyai', 'dogiyai'],
#  ['Dharmasraya', 'dharmasraya'],
#  ['Depok', 'depok'],
#  ['Denpasar', 'denpasar'],
#  ['Demak', 'demak'],
#  ['Deli Serdang', 'deliserdang'],
#  ['Deiyai', 'deiyai'],
#  ['Dairi', 'dairi'],
#  ['Cirebon', 'cirebon'],
#  ['Cirebon', 'cirebon'],
#  ['Cimahi', 'cimahi'],
#  ['Cilegon', 'cilegon'],
#  ['Cilacap', 'cilacap'],
#  ['Cianjur', 'cianjur'],
#  ['Ciamis', 'ciamis'],
#  ['Buton Utara', 'butonutara'],
#  ['Buton Tengah', 'butontengah'],
#  ['Buton Selatan', 'butonselatan'],
#  ['Buton', 'buton'],
#  ['Buru Selatan', 'buruselatan'],
#  ['Buru', 'buru'],
#  ['Buol', 'buol'],
#  ['Bungo', 'bungo'],
#  ['Bulungan', 'bulungan'],
#  ['Bulukumba', 'bulukumba'],
#  ['Buleleng', 'buleleng'],
#  ['Bukittinggi', 'bukittinggi'],
#  ['Brebes', 'brebes'],
#  ['Boyolali', 'boyolali'],
#  ['Boven Digoel', 'bovendigoel'],
#  ['Bontang', 'bontang'],
#  ['Bone Bolango', 'bonebolango'],
#  ['Bone', 'bone'],
#  ['Bondowoso', 'bondowoso'],
#  ['Bombana', 'bombana'],
#  ['Bolaang Mongondow Utara', 'bolaangmongondowutara'],
#  ['Bolaang Mongondow Timur', 'bolaangmongondowtimur'],
#  ['Bolaang Mongondow Selatan', 'bolaangmongondowselatan'],
#  ['Bolaang Mongondow', 'bolaangmongondow'],
#  ['Bojonegoro', 'bojonegoro'],
#  ['Bogor', 'bogor'],
#  ['Bogor', 'bogor'],
#  ['Boalemo', 'boalemo'],
#  ['Blora', 'blora'],
#  ['Blitar', 'blitar'],
#  ['Blitar', 'blitar'],
#  ['Bitung', 'bitung'],
#  ['Bireuen', 'bireuen'],
#  ['Bintan', 'bintan'],
#  ['Binjai', 'binjai'],
#  ['Bima', 'bima'],
#  ['Bima', 'bima'],
#  ['Biak Numfor', 'biaknumfor'],
#  ['Berau', 'berau'],
#  ['Bengkulu Utara', 'bengkuluutara'],
#  ['Bengkulu Tengah', 'bengkulutengah'],
#  ['Bengkulu Selatan', 'bengkuluselatan'],
#  ['Bengkulu', 'bengkulu'],
#  ['Bengkayang', 'bengkayang'],
#  ['Bengkalis', 'bengkalis'],
#  ['Bener Meriah', 'benermeriah'],
#  ['Belu', 'belu'],
#  ['Belitung Timur', 'belitungtimur'],
#  ['Belitung', 'belitung'],
#  ['Bekasi', 'bekasi'],
#  ['Bekasi', 'bekasi'],
#  ['Bau-Bau', 'baubau'],
#  ['Batu Bara', 'batubara'],
#  ['Batu', 'batu'],
#  ['Batang Hari', 'batanghari'],
#  ['Batang', 'batang'],
#  ['Batam', 'batam'],
#  ['Barru', 'barru'],
#  ['Barito Utara', 'baritoutara'],
#  ['Barito Timur', 'baritotimur'],
#  ['Barito Selatan', 'baritoselatan'],
#  ['Barito Kuala', 'baritokuala'],
#  ['Banyuwangi', 'banyuwangi'],
#  ['Banyumas', 'banyumas'],
#  ['Banyuasin', 'banyuasin'],
#  ['Bantul', 'bantul'],
#  ['Bantaeng', 'bantaeng'],
#  ['Banjarnegara', 'banjarnegara'],
#  ['Banjarmasin', 'banjarmasin'],
#  ['Banjarbaru', 'banjarbaru'],
#  ['Banjar', 'banjar'],
#  ['Banjar', 'banjar'],
#  ['Bangli', 'bangli'],
#  ['Bangkalan', 'bangkalan'],
#  ['Bangka Tengah', 'bangkatengah'],
#  ['Bangka Selatan', 'bangkaselatan'],
#  ['Bangka Barat', 'bangkabarat'],
#  ['Bangka', 'bangka'],
#  ['Banggai Laut', 'banggailaut'],
#  ['Banggai Kepulauan', 'banggaikepulauan'],
#  ['Banggai', 'banggai'],
#  ['Bandung Barat', 'bandungbarat'],
#  ['Bandung', 'bandung'],
#  ['Bandung', 'bandung'],
#  ['Bandar Lampung', 'bandarlampung'],
#  ['Banda Aceh', 'bandaaceh'],
#  ['Balikpapan', 'balikpapan'],
#  ['Balangan', 'balangan'],
#  ['Badung', 'badung'],
#  ['Asmat', 'asmat'],
#  ['Asahan', 'asahan'],
#  ['Ambon', 'ambon'],
#  ['Alor', 'alor'],
#  ['Agam', 'agam'],
#  ['Aceh Utara', 'acehutara'],
#  ['Aceh Timur', 'acehtimur'],
#  ['Aceh Tenggara', 'acehtenggara'],
#  ['Aceh Tengah', 'acehtengah'],
#  ['Aceh Tamiang', 'acehtamiang'],
#  ['Aceh Singkil', 'acehsingkil'],
#  ['Aceh Selatan', 'acehselatan'],
#  ['Aceh Jaya', 'acehjaya'],
#  ['Aceh Besar', 'acehbesar'],
#  ['Aceh Barat Daya', 'acehbaratdaya'],
#  ['Aceh Barat', 'acehbarat']]

# %%
mc2p = mc2p.mapk(stransform)
mc2p
# Out:
# {'yogyakarta': ['DI Yogyakarta'], 'yalimo': ['Papua'], 'yahukimo': ['Papua'], 'wonosobo': ['Jawa Tengah'], 'wonogiri': ['Jawa Tengah'], 'waykanan': ['Lampung'], 'waropen': ['Papua'], 'wakatobi': ['Sulawesi Tenggara'], 'wajo': ['Sulawesi Selatan'], 'tulungagung': ['Jawa Timur'], 'tulangbawangbarat': ['Lampung'], 'tulangbawang': ['Lampung'], 'tuban': ['Jawa Timur'], 'tual': ['Maluku'], 'trenggalek': ['Jawa Timur'], 'torajautara': ['Sulawesi Selatan'], 'tomohon': ['Sulawesi Utara'], 'tolikara': ['Papua'], 'tolitoli': ['Sulawesi Tengah'], 'tojounauna': ['Sulawesi Tengah'], 'tobasamosir': ['Sumatera Utara'], 'timortengahutara': ['Nusa Tenggara Timur (NTT)'], 'timortengahselatan': ['Nusa Tenggara Timur (NTT)'], 'tidorekepulauan': ['Maluku Utara'], 'ternate': ['Maluku Utara'], 'temanggung': ['Jawa Tengah'], 'telukwondama': ['Papua Barat'], 'telukbintuni': ['Papua Barat'], 'tegal': ['Jawa Tengah'], 'tebo': ['Jambi'], 'tebingtinggi': ['Sumatera Utara'], 'tasikmalaya': ['Jawa Barat'], 'tarakan': ['Kalimantan Utara'], 'tapin': ['Kalimantan Selatan'], 'tapanuliutara': ['Sumatera Utara'], 'tapanulitengah': ['Sumatera Utara'], 'tapanuliselatan': ['Sumatera Utara'], 'tanjungpinang': ['Kepulauan Riau'], 'tanjungjabungtimur': ['Jambi'], 'tanjungjabungbarat': ['Jambi'], 'tanjungbalai': ['Sumatera Utara'], 'tanggamus': ['Lampung'], 'tangerangselatan': ['Banten'], 'tangerang': ['Banten'], 'tanahlaut': ['Kalimantan Selatan'], 'tanahdatar': ['Sumatera Barat'], 'tanahbumbu': ['Kalimantan Selatan'], 'tanatoraja': ['Sulawesi Selatan'], 'tanatidung': ['Kalimantan Utara'], 'tambrauw': ['Papua Barat'], 'takalar': ['Sulawesi Selatan'], 'tabanan': ['Bali'], 'tabalong': ['Kalimantan Selatan'], 'surakarta': ['Jawa Tengah'], 'surabaya': ['Jawa Timur'], 'supiori': ['Papua'], 'sungaipenuh': ['Jambi'], 'sumenep': ['Jawa Timur'], 'sumedang': ['Jawa Barat'], 'sumbawabarat': ['Nusa Tenggara Barat (NTB)'], 'sumbawa': ['Nusa Tenggara Barat (NTB)'], 'sumbatimur': ['Nusa Tenggara Timur (NTT)'], 'sumbatengah': ['Nusa Tenggara Timur (NTT)'], 'sumbabaratdaya': ['Nusa Tenggara Timur (NTT)'], 'sumbabarat': ['Nusa Tenggara Timur (NTT)'], 'sukoharjo': ['Jawa Tengah'], 'sukamara': ['Kalimantan Tengah'], 'sukabumi': ['Jawa Barat'], 'subulussalam': ['Aceh (NAD)'], 'subang': ['Jawa Barat'], 'sragen': ['Jawa Tengah'], 'sorongselatan': ['Papua Barat'], 'sorong': ['Papua Barat'], 'soppeng': ['Sulawesi Selatan'], 'solokselatan': ['Sumatera Barat'], 'solok': ['Sumatera Barat'], 'sleman': ['DI Yogyakarta'], 'situbondo': ['Jawa Timur'], 'sintang': ['Kalimantan Barat'], 'sinjai': ['Sulawesi Selatan'], 'singkawang': ['Kalimantan Barat'], 'simeulue': ['Aceh (NAD)'], 'simalungun': ['Sumatera Utara'], 'sikka': ['Nusa Tenggara Timur (NTT)'], 'sijunjung': ['Sumatera Barat'], 'sigi': ['Sulawesi Tengah'], 'sidoarjo': ['Jawa Timur'], 'sidenrengrappang': ['Sulawesi Selatan'], 'sibolga': ['Sumatera Utara'], 'siak': ['Riau'], 'seruyan': ['Kalimantan Tengah'], 'serdangbedagai': ['Sumatera Utara'], 'serang': ['Banten'], 'serambagiantimur': ['Maluku'], 'serambagianbarat': ['Maluku'], 'semarang': ['Jawa Tengah'], 'seluma': ['Bengkulu'], 'sekadau': ['Kalimantan Barat'], 'sawahlunto': ['Sumatera Barat'], 'sarolangun': ['Jambi'], 'sarmi': ['Papua'], 'sanggau': ['Kalimantan Barat'], 'sampang': ['Jawa Timur'], 'samosir': ['Sumatera Utara'], 'sambas': ['Kalimantan Barat'], 'samarinda': ['Kalimantan Timur'], 'salatiga': ['Jawa Tengah'], 'saburaijua': ['Nusa Tenggara Timur (NTT)'], 'sabang': ['Aceh (NAD)'], 'rotendao': ['Nusa Tenggara Timur (NTT)'], 'rokanhulu': ['Riau'], 'rokanhilir': ['Riau'], 'rembang': ['Jawa Tengah'], 'rejanglebong': ['Bengkulu'], 'rajaampat': ['Papua Barat'], 'purworejo': ['Jawa Tengah'], 'purwakarta': ['Jawa Barat'], 'purbalingga': ['Jawa Tengah'], 'puncakjaya': ['Papua'], 'puncak': ['Papua'], 'pulautaliabu': ['Maluku Utara'], 'pulaumorotai': ['Maluku Utara'], 'pulangpisau': ['Kalimantan Tengah'], 'probolinggo': ['Jawa Timur'], 'pringsewu': ['Lampung'], 'prabumulih': ['Sumatera Selatan'] ...

# %%
mc2p.bj()
# Out:
# {'banjar': ['Jawa Barat', 'Kalimantan Selatan']}
# False

# %%
mc2p['banjar'] = ["Jawa Barat"]

# %%
mc2p.bj()
# Out:
# True

# %%
c_synonyms = """
KABUPATEN ACEH BESAR -> acehbesar
KOTA BANDAR LAMPUNG -> bandar lampung
KABUPATEN SLEMAN -> sleman
KABUPATEN CIREBON -> cirebon
KOTA TANGERANG -> tangerang
KOTA TANGERANG SELATAN -> tangerangselatan
KOTA DEPOK -> depok
KABUPATEN GUNUNGKIDUL -> gunungkidul
KABUPATEN SIDOARJO -> sidoarjo
KABUPATEN PASURUAN -> pasuruan
KOTA SURABAYA -> surabaya
KABUPATEN PURWAKARTA -> purwakarta
KABUPATEN CIANJUR -> cianjur
KABUPATEN BEKASI -> bekasi
KOTA JAMBI -> jambi
KABUPATEN BOGOR -> bogor
KABUPATEN KARAWANG -> karawang
KABUPATEN BOGOR -> bogor
KOTA BANDUNG -> bandung
KABUPATEN BANDUNG BARAT -> bandungbarat
KABUPATEN SUKABUMI -> sukabumi
KADUPATEN GROBOGAN -> grobogan
KABUPATEN MOJOKERTO -> mojokerto
KABUPATEN JOMBANG -> jombang
KABUPATEN SAMPANG -> sampang
KABUPATEN SUKOHARJO -> sukoharjo
arangasem': ['karangasem'], 'kabupatenpandeglang': ['pandeglang'], 'kotasamarinda': ['samarinda'], 'kabupatenkutaikartanegara': ['kutaikartanegara'], 'kotabatam': ['batam'], 'kotapalembang': ['palembang'], 'kabupatenlombokbarat': ['lombokbarat'], 'kotapekanbaru': ['pekanbaru'], 'kabupatensiak': ['siak'], 'kotasolok': ['solok'], 'kotamanado': ['manado'], 'kotapadang': ['padang'], 'kotatebingtinggi': ['tebingtinggi'], 'kabupatenmuaraenim': ['muaraenim'], 'kabupatenlumajang': ['lumajang'], 'kotabogor': ['bogor'], 'kotapalu': ['palu'], 'kabupatengowa': ['gowa'], 'kotabekasi': ['bekasi'], 'kabupatenmaros': ['maros'], 'kotamedan': ['medan'], 'kabupatentangerang': ['tangerang'], 'kabupatenkediri': ['kediri'], 'kotakupang': ['kupang'], 'kabupatenminahasa': ['minahasa'], 'kabupatenminahasautara': ['minahasautara'], 'kabupatenbojonegoro': ['bojonegoro'], 'kabupatenbandung': ['bandung'], 'kabupatenpadangpariaman': ['padangpariaman'], 'kotabalikpapan': ['balikpapan'], 'kabupatenogankomeringulutimur': ['ogankomeringulutimur'], 'kotakotamobagu': ['kotamobagu'], 'kabupatenwonosobo': ['wonosobo']}

# %%
c_synonyms.bj()
# Out:
# True

# %%
c_synonyms.reverse() in mc2p
# Out:
# True

# %%
mc2p += c_synonyms.mapv(mc2p)

# %%
md2c = Map(d2c)
md2c
# Out:
# {'2 X 11 Enam Lingkuang': ['Padang Pariaman'], '2 X 11 Kayu Tanam': ['Padang Pariaman'], 'Abab': ['Penukal Abab Lematang Ilir'], 'Abang': ['Karangasem'], 'Abeli': ['Kendari'], 'Abenaho': ['Yalimo'], 'Abepura': ['Jayapura'], 'Abiansemal': ['Badung'], 'Aboy': ['Pegunungan Bintang'], 'Abuki': ['Konawe'], 'Abun': ['Tambrauw'], 'Abung Barat': ['Lampung Utara'], 'Abung Kunang': ['Lampung Utara'], 'Abung Pekurun': ['Lampung Utara'], 'Abung Selatan': ['Lampung Utara'], 'Abung Semuli': ['Lampung Utara'], 'Abung Surakarta': ['Lampung Utara'], 'Abung Tengah': ['Lampung Utara'], 'Abung Timur': ['Lampung Utara'], 'Abung Tinggi': ['Lampung Utara'], 'Adian Koting': ['Tapanuli Utara'], 'Adiluwih (Adi Luwih)': ['Pringsewu'], 'Adimulyo': ['Kebumen'], 'Adipala': ['Cilacap'], 'Adiwerna': ['Tegal'], 'Adonara': ['Flores Timur'], 'Adonara Barat': ['Flores Timur'], 'Adonara Tengah': ['Flores Timur'], 'Adonara Timur': ['Flores Timur'], 'Aek Bilah': ['Tapanuli Selatan'], 'Aek Kuasan': ['Asahan'], 'Aek Kuo': ['Labuhanbatu Utara'], 'Aek Ledong': ['Asahan'], 'Aek Nabara Barumun': ['Padang Lawas'], 'Aek Natas': ['Labuhanbatu Utara'], 'Aek Songsongan': ['Asahan'], 'Aere': ['Kolaka Timur'], 'Aertembaga (Bitung Timur)': ['Bitung'], 'Aesesa': ['Nagekeo
nusa tenggara barat'], 'alasbarat': ['nusa tenggara barat'], 'alasa': ['sumatera utara'], 'alasatalumuzoi': ['sumatera utara'], 'alemsom': ['papua'], 'alian': ['jawa tengah'], 'aliyan': ['jawa tengah'], 'alla': ['sulawesi selatan'], 'alok': ['nusa tenggara timur'], 'alokbarat': ['nusa tenggara timur'], 'aloktimur': ['nusa tenggara timur'], 'alorbaratdaya': ['nusa tenggara timur'], 'alorbaratlaut': ['nusa tenggara timur'], 'alorselatan': ['nusa tenggara timur'], 'alortengahutara': ['nusa tenggara timur'], 'alortimur': ['nusa tenggara timur'], 'alortimurlaut': ['nusa tenggara timur'], 'alu': ['sulawesi barat'], 'allu': ['sulawesi barat'], 'aluhaluh': ['jawa barat'], 'amabioefeto': ['nusa tenggara timur'], 'amabioefetotimur': ['nusa tenggara timur'], 'amahai': ['maluku'], 'amalatu': ['maluku'], 'amali': ['sulawesi selatan'], 'amanatunselatan': ['n ...

# %%
md2c.bj()
# Out:
# {'airhitam': ['Sarolangun', 'Lampung Barat']}
# {'alama': ['Mimika', 'Nduga']}
# {'ambalau': ['Buru Selatan', 'Sintang']}
# {'ambarawa': ['Pringsewu', 'Semarang']}
# {'ivnagari': ['Sijunjung', 'Agam']}
# {'ampelgading': ['Pemalang', 'Malang']}
# {'angsana': ['Pandeglang', 'Tanah Bumbu']}
# {'arjasa': ['Jember', 'Situbondo', 'Sumenep']}
# {'badau': ['Kapuas Hulu', 'Belitung']}
# {'balusu': ['Barru', 'Toraja Utara']}
# {'bandar': ['Batang', 'Simalungun', 'Pacitan', 'Bener Meriah']}
# {'bandung': ['Serang', 'Tulungagung']}
# {'bangko': ['Merangin', 'Rokan Hilir']}
# {'pusako': ['Siak', 'Rokan Hilir']}
# {'bangunpurba': ['Rokan Hulu', 'Deli Serdang']}
# {'banjar': ['Pandeglang', 'Buleleng', 'Banjar']}
# {'banjaran': ['Majalengka', 'Bandung']}
# {'banjarsari': ['Ciamis', 'Lebak', 'Surakarta']}
# {'banyumas': ['Pringsewu', 'Banyumas']}
# {'banyuputih': ['Batang', 'Situbondo']}
# {'baros': ['Sukabumi', 'Serang']}
# {'batang': ['Batang', 'Jeneponto']}
# {'batuampar': ['Kubu Raya', 'Seruyan', 'Kutai Timur', 'Batam', 'Tanah Laut']}
# {'batuputih': ['Timor Tengah Selatan', 'Sumenep', 'Tulang Bawang Barat', 'Kolaka Utara', 'Berau']}
# {'bawang': ['Batang', 'Banjarnegara']}
# {'bayan': ['Lombok Utara', 'Purworejo']}
# {'beji': ['Depok', 'Pasuruan']}
# {'belimbing': ['Muara Enim', 'Melawi']}
# {'belitang': ['Ogan Komering Ulu Timur', 'Sekadau']}
# {'besuki': ['Situbondo', 'Tulungagung']}
# {'biau': ['Gorontalo Utara', 'Buol']}
# {'binangun': ['Cilacap', 'Blitar']}
# {'binuang': ['Polewali Mandar', 'Tapin', 'Serang']}
# {'bojong': ['Purwakarta', 'Pekalongan', 'Pandeglang', 'Tegal']}
# {'bojongsari': ['Depok', 'Purbalingga']}
# {'bola': ['Wajo', 'Sikka']}
# {'bone': ['Bone Bolango', 'Muna']}
# {'bringin': ['Ngawi', 'Semarang']}
# {'bukitbatu': ['Palangka Raya', 'Bengkalis']}
# {'bukitraya': ['Pekanbaru', 'Katingan']}
# {'bulu': ['Rembang', 'Sukoharjo', 'Temanggung']}
# {'bumiagung': ['Lampung Timur', 'Way Kanan']}
# {'bungamayang': ['Lampung Utara', 'Ogan Komering Ulu Timur']}
# {'bungursari': ['Purwakarta', 'Tasikmalaya']}
# {'campaka': ['Purwakarta', 'Cianjur']}
# {'candipuro': ['Lampung Selatan', 'Lumajang']}
# {'caringin': ['Garut', 'Sukabumi', 'Bogor']}
# {'cempaka': ['Banjarbaru', 'Ogan Komering Ulu Timur']}
# {'cenrana': ['Bone', 'Maros']}
# {'ciawi': ['Tasikmalaya', 'Bogor']}
# {'cibadak': ['Lebak', 'Sukabumi']}
# {'cibalong': ['Garut', 'Tasikmalaya']}
# {'cibatu': ['Garut', 'Purwakarta']}
# {'cibeber': ['Cilegon', 'Lebak', 'Cianjur']}
# {'cibeureum': ['Tasikmalaya', 'Sukabumi', 'Kuningan']}
# {'cibinong': ['Cianjur', 'Bogor']}
# {'cibitung': ['Sukabumi', 'Bekasi', 'Pandeglang']}
# {'cidadap': ['Sukabumi', 'Bandung']}
# {'cidahu': ['Sukabumi', 'Kuningan']}
# {'cidolog': ['Ciamis', 'Sukabumi']}
# {'cigugur': ['Kuningan', 'Pangandaran']}
# {'ciledug': ['Tangerang', 'Cirebon']}
# {'cimanggu': ['Sukabumi', 'Cilacap', 'Pandeglang']}
# {'ciomas': ['Bogor', 'Serang']}
# {'cipanas': ['Lebak', 'Cianjur']}
# {'cipayung': ['Jakarta Timur', 'Depok']}
# {'cipeundeuy': ['Subang', 'Bandung Barat']}
# {'cisarua': ['Sumedang', 'Bandung Barat', 'Bogor']}
# {'curug': ['Tangerang', 'Serang']}
# {'dawuan': ['Subang', 'Majalengka']}
# {'dendang': ['Belitung Timur', 'Tanjung Jabung Timur']}
# {'depok': ['Sleman', 'Cirebon']}
# {'donorojo': ['Jepara', 'Pacitan']}
# {'dukun': ['Gresik', 'Magelang']}
# {'gabus': ['Pati', 'Grobogan']}
# {'gadingrejo': ['Pringsewu', 'Pasuruan']}
# {'galang': ['Deli Serdang', 'Toli-Toli', 'Batam']}
# {'galis': ['Bangkalan', 'Pamekasan']}
# {'gandusari': ['Blitar', 'Trenggalek']}
# {'gayam': ['Bojonegoro', 'Sumenep']}
# {'gebang': ['Langkat', 'Purworejo', 'Cirebon']}
# {'gedangan': ['Sidoarjo', 'Malang']}
# {'geger': ['Bangkalan', 'Madiun']}
# {'gempol': ['Pasuruan', 'Cirebon']}
# {'genteng': ['Banyuwangi', 'Surabaya']}
# {'glagah': ['Banyuwangi', 'Lamongan']}
# {'gondang': ['Bojonegoro', 'Tulungagung', 'Mojokerto', 'Nganjuk', 'Sragen']}
# {'grabag': ['Purworejo', 'Magelang']}
# {'grogol': ['Sukoharjo', 'Kediri']}
# {'gunungmeriah': ['Deli Serdang', 'Aceh Singkil']}
# {'gunungsari': ['Lombok Barat', 'Serang']}
# {'indrajaya': ['Aceh Jaya', 'Pidie']}
# {'jabung': ['Malang', 'Lampung Timur']}
# {'jati': ['Blora', 'Kudus']}
# {'jatibarang': ['Brebes', 'Indramayu']}
# {'jatinegara': ['Jakarta Timur', 'Tegal']}
# {'jatiroto': ['Wonogiri', 'Lumajang']}
# {'jetis': ['Yogyakarta', 'Ponorogo', 'Bantul', 'Mojokerto']}
# {'jeumpa': ['Bireuen', 'Aceh Barat Daya']}
# {'jombang': ['Cilegon', 'Jombang', 'Jember']}
# {'kademangan': ['Blitar', 'Probolinggo']}
# {'kadipaten': ['Tasikmalaya', 'Majalengka']}
# {'kalibawang': ['Wonosobo', 'Kulon Progo']}
# {'kaliwungu': ['Kendal', 'Semarang', 'Kudus']}
# {'kalumpang': ['Mamuju', 'Hulu Sungai Selatan']}
# {'kandangan': ['Hulu Sungai Selatan', 'Kediri', 'Temanggung']}
# {'kandis': ['Ogan Ilir', 'Siak']}
# {'karangjaya': ['Tasikmalaya', 'Musi Rawas Utara']}
# {'karangtengah': ['Demak', 'Wonogiri', 'Garut', 'Cianjur', 'Tangerang']}
# {'karangan': ['Trenggalek', 'Kutai Timur']}
# {'karanganyar': ['Pekalongan', 'Demak', 'Purbalingga', 'Ngawi', 'Kebumen', 'Karanganyar']}
# {'karangrejo': ['Magetan', 'Tulungagung']}
# {'karas': ['Fakfak', 'Magetan']}
# {'kartoharjo': ['Magetan', 'Madiun']}
# {'kauman': ['Ponorogo', 'Tulungagung']}
# {'kayanhilir': ['Sintang', 'Malinau']}
# {'kayanhulu': ['Sintang', 'Malinau']}
# {'kebonagung': ['Demak', 'Pacitan']}
# {'kedawung': ['Sragen', 'Cirebon']}
# {'kediri': ['Tabanan', 'Lombok Barat']}
# {'kedungbanteng': ['Banyumas', 'Tegal']}
# {'kemiri': ['Tangerang', 'Purworejo']}
# {'kemuning': ['Indragiri Hilir', 'Palembang']}
# {'kendal': ['Kendal', 'Ngawi']}
# {'kesamben': ['Jombang', 'Blitar']}
# {'ketapang': ['Lampung Selatan', 'Sampang']}
# {'konda': ['Konawe Selatan', 'Sorong Selatan', 'Tolikara']}
# {'kotaagung': ['Tanggamus', 'Lahat']}
# {'kotabaru': ['Jambi', 'Ende', 'Karawang']}
# {'kotobaru': ['Sungaipenuh', 'Dharmasraya']}
# {'kradenan': ['Blora', 'Grobogan']}
# {'kranggan': ['Mojokerto', 'Temanggung']}
# {'kraton': ['Yogyakarta', 'Pasuruan']}
# {'kroya': ['Cilacap', 'Indramayu']}
# {'kuala': ['Langkat', 'Bireuen', 'Nagan Raya']}
# {'kubu': ['Kubu Raya', 'Rokan Hilir', 'Karangasem', 'Tolikara']}
# {'kuranji': ['Padang', 'Tanah Bumbu']}
# {'kuripan': ['Barito Kuala', 'Lombok Barat', 'Probolinggo']}
# {'labuan': ['Pandeglang', 'Donggala']}
# {'labuhanhaji': ['Lombok Timur', 'Aceh Selatan']}
# {'labuhanratu': ['Bandar Lampung', 'Lampung Timur']}
# {'lais': ['Musi Banyuasin', 'Bengkulu Utara']}
# {'larangan': ['Pamekasan', 'Brebes', 'Tangerang']}
# {'lebakwangi': ['Kuningan', 'Serang']}
# {'leles': ['Garut', 'Cianjur']}
# {'lemahabang': ['Karawang', 'Cirebon']}
# {'lembang': ['Bandung Barat', 'Pinrang']}
# {'lembo': ['Morowali Utara', 'Konawe Utara']}
# {'lengkong': ['Sukabumi', 'Nganjuk', 'Bandung']}
# {'limapuluh': ['Batu Bara', 'Pekanbaru']}
# {'losari': ['Brebes', 'Cirebon']}
# {'lumbang': ['Probolinggo', 'Pasuruan']}
# {'maja': ['Lebak', 'Majalengka']}
# {'majalaya': ['Karawang', 'Bandung']}
# {'mare': ['Bone', 'Maybrat']}
# {'martapura': ['Ogan Komering Ulu Timur', 'Banjar']}
# {'meranti': ['Landak', 'Asahan']}
# {'mesuji': ['Mesuji', 'Ogan Komering Ilir']}
# {'mijen': ['Demak', 'Semarang']}
# {'muara': ['Tapanuli Utara', 'Lanny Jaya', 'Puncak Jaya']}
# {'muaradua': ['Lhokseumawe', 'Ogan Komering Ulu Selatan']}
# {'mugi': ['Nduga', 'Yahukimo']}
# {'ngadirojo': ['Wonogiri', 'Pacitan']}
# {'ngasem': ['Bojonegoro', 'Kediri']}
# {'ngawen': ['Blora', 'Gunung Kidul', 'Klaten']}
# {'ngemplak': ['Boyolali', 'Sleman']}
# {'ngoro': ['Jombang', 'Mojokerto']}
# {'nguntoronadi': ['Wonogiri', 'Magetan']}
# {'pabuaran': ['Sukabumi', 'Subang', 'Serang', 'Cirebon']}
# {'pacet': ['Cianjur', 'Mojokerto', 'Bandung']}
# {'pagardewa': ['Lampung Barat', 'Tulang Bawang Barat']}
# {'pagelaran': ['Pringsewu', 'Cianjur', 'Malang', 'Pandeglang']}
# {'pakem': ['Sleman', 'Bondowoso']}
# {'pakis': ['Malang', 'Magelang']}
# {'pakisaji': ['Malang', 'Jepara']}
# {'palangga': ['Konawe Selatan', 'Gowa']}
# {'pameungpeuk': ['Garut', 'Bandung']}
# {'pamulihan': ['Garut', 'Sumedang']}
# {'panggungrejo': ['Blitar', 'Pasuruan']}
# {'pantaicermin': ['Solok', 'Serdang Bedagai']}
# {'panti': ['Jember', 'Pasaman']}
# {'parigi': ['Parigi Moutong', 'Pangandaran', 'Muna', 'Gowa']}
# {'pasawahan': ['Purwakarta', 'Kuningan']}
# {'paseh': ['Sumedang', 'Bandung']}
# {'pasirputih': ['Nduga', 'Muna']}
# {'pattallassang': ['Takalar', 'Gowa']}
# {'pauh': ['Sarolangun', 'Padang']}
# {'payung': ['Bangka Selatan', 'Karo']}
# {'payungsekaki': ['Solok', 'Pekanbaru']}
# {'plered': ['Purwakarta', 'Cirebon']}
# {'prambanan': ['Sleman', 'Klaten']}
# {'prambon': ['Sidoarjo', 'Nganjuk']}
# {'pulaulaut': ['Kotabaru', 'Natuna']}
# {'pulausembilan': ['Kotabaru', 'Sinjai']}
# {'pulautiga': ['Natuna', 'Asmat']}
# {'pulosari': ['Pemalang', 'Pandeglang']}
# {'purwadadi': ['Ciamis', 'Subang']}
# {'purwakarta': ['Cilegon', 'Purwakarta']}
# {'purwodadi': ['Pasuruan', 'Musi Rawas', 'Purworejo', 'Grobogan']}
# {'purworejo': ['Pasuruan', 'Purworejo']}
# {'purwosari': ['Bojonegoro', 'Pasuruan', 'Gunung Kidul']}
# {'rajabasa': ['Lampung Selatan', 'Bandar Lampung']}
# {'rambutan': ['Banyuasin', 'Tebing Tinggi']}
# {'rejoso': ['Nganjuk', 'Pasuruan']}
# {'rembang': ['Rembang', 'Pasuruan', 'Purbalingga']}
# {'rumbia': ['Jeneponto', 'Bombana', 'Lampung Tengah']}
# {'salawatitengah': ['Raja Ampat', 'Sorong']}
# {'sampang': ['Cilacap', 'Sampang']}
# {'sawahan': ['Nganjuk', 'Madiun', 'Surabaya']}
# {'sawang': ['Aceh Utara', 'Aceh Selatan']}
# {'sawangan': ['Depok', 'Magelang']}
# {'sei': ['Batam', 'Mempawah', 'Banjar', 'Labuhanbatu Selatan']}
# {'sungaipinang': ['Ogan Ilir', 'Samarinda', 'Banjar']}
# {'selat': ['Kapuas', 'Karangasem']}
# {'sendana': ['Majene', 'Palopo']}
# {'serbajadi': ['Aceh Timur', 'Serdang Bedagai']}
# {'setu': ['Bekasi', 'Tangerang Selatan']}
# {'siantan': ['Kepulauan Anambas', 'Mempawah']}
# {'sidoharjo': ['Wonogiri', 'Sragen']}
# {'sidorejo': ['Magetan', 'Salatiga']}
# {'simpangempat': ['Karo', 'Tanah Bumbu', 'Asahan', 'Banjar']}
# {'simpangkanan': ['Aceh Singkil', 'Rokan Hilir']}
# {'simpangtiga': ['Aceh Besar', 'Pidie']}
# {'sindang': ['Majalengka', 'Indramayu']}
# {'singkil': ['Manado', 'Aceh Singkil']}
# {'siriwo': ['Nabire', 'Paniai']}
# {'sobang': ['Lebak', 'Pandeglang']}
# {'sooko': ['Ponorogo', 'Mojokerto']}
# {'soreang': ['Parepare', 'Bandung']}
# {'sragi': ['Pekalongan', 'Lampung Selatan']}
# {'subah': ['Sambas', 'Batang']}
# {'subang': ['Subang', 'Kuningan']}
# {'sukakarya': ['Bekasi', 'Musi Rawas', 'Sabang']}
# {'sukabumi': ['Sukabumi', 'Bandar Lampung']}
# {'sukadana': ['Ciamis', 'Kayong Utara', 'Lampung Timur']}
# {'sukajadi': ['Pekanbaru', 'Bandung']}
# {'sukajaya': ['Sabang', 'Bogor']}
# {'sukamakmur': ['Aceh Besar', 'Bogor']}
# {'sukaraja': ['Tasikmalaya', 'Sukabumi', 'Bogor', 'Seluma']}
# {'sukarame': ['Tasikmalaya', 'Bandar Lampung']}
# {'sukaresmi': ['Garut', 'Cianjur', 'Pandeglang']}
# {'sukasari': ['Purwakarta', 'Sumedang', 'Subang', 'Bandung']}
# {'sukatani': ['Purwakarta', 'Bekasi']}
# {'sukodono': ['Sragen', 'Sidoarjo', 'Lumajang']}
# {'sukoharjo': ['Pringsewu', 'Sukoharjo', 'Wonosobo']}
# {'sukolilo': ['Pati', 'Surabaya']}
# {'sukomoro': ['Magetan', 'Nganjuk']}
# {'sukorejo': ['Kendal', 'Ponorogo', 'Blitar', 'Pasuruan']}
# {'sumber': ['Rembang', 'Probolinggo', 'Cirebon']}
# {'sumberjaya': ['Majalengka', 'Lampung Barat']}
# {'sumberejo': ['Tanggamus', 'Bojonegoro']}
# {'sungairaya': ['Hulu Sungai Selatan', 'Kubu Raya', 'Bengkayang', 'Aceh Timur']}
# {'sungairumbai': ['Dharmasraya', 'Muko Muko']}
# {'surusuru': ['Asmat', 'Yahukimo']}
# {'suruh': ['Semarang', 'Trenggalek']}
# {'susukan': ['Banjarnegara', 'Semarang', 'Cirebon']}
# {'tabang': ['Mamasa', 'Kutai Kartanegara']}
# {'tagime': ['Jayawijaya', 'Tolikara']}
# {'tagineri': ['Jayawijaya', 'Tolikara']}
# {'talangpadang': ['Tanggamus', 'Empat Lawang']}
# {'talawi': ['Batu Bara', 'Sawah Lunto']}
# {'talun': ['Pekalongan', 'Blitar', 'Cirebon']}
# {'taman': ['Pemalang', 'Sidoarjo', 'Madiun']}
# {'tamansari': ['Pangkal Pinang', 'Jakarta Barat', 'Tasikmalaya', 'Boyolali', 'Bogor']}
# {'tambak': ['Banyumas', 'Gresik']}
# {'tambaksari': ['Ciamis', 'Surabaya']}
# {'tambora': ['Jakarta Barat', 'Bima']}
# {'tanahabang': ['Jakarta Pusat', 'Penukal Abab Lematang Ilir']}
# {'tanahmerah': ['Bangkalan', 'Indragiri Hilir']}
# {'tanjung': ['Tabalong', 'Lombok Utara', 'Brebes']}
# {'tanjungharapan': ['Solok', 'Paser']}
# {'tanjungraja': ['Lampung Utara', 'Ogan Ilir']}
# {'tanjungraya': ['Agam', 'Mesuji']}
# {'tanjungsari': ['Lampung Selatan', 'Sumedang', 'Bogor', 'Gunung Kidul']}
# {'tebingtinggi': ['Empat Lawang', 'Balangan', 'Tanjung Jabung Barat', 'Serdang Bedagai', 'Kepulauan Meranti']}
# {'tegalrejo': ['Yogyakarta', 'Magelang']}
# {'tegalsari': ['Banyuwangi', 'Surabaya']}
# {'tegalwaru': ['Purwakarta', 'Karawang']}
# {'tellulimpoe': ['Bone', 'Sidenreng Rappang', 'Sinjai']}
# {'telukdalam': ['Asahan', 'Simeulue', 'Nias Selatan']}
# {'telukpandan': ['Kutai Timur', 'Pesawaran']}
# {'tempuran': ['Karawang', 'Magelang']}
# {'tikala': ['Manado', 'Toraja Utara']}
# {'tomini': ['Parigi Moutong', 'Bolaang Mongondow Selatan']}
# {'tompobulu': ['Bantaeng', 'Maros', 'Gowa']}
# {'trucuk': ['Bojonegoro', 'Klaten']}
# {'tugu': ['Semarang', 'Trenggalek']}
# {'tungkalilir': ['Banyuasin', 'Tanjung Jabung Barat']}
# {'turi': ['Lamongan', 'Sleman']}
# {'ujanmas': ['Muara Enim', 'Kepahiang']}
# {'ujungbatu': ['Rokan Hulu', 'Padang Lawas Utara']}
# {'wamesa': ['Teluk Bintuni', 'Teluk Wondama']}
# {'wonodadi': ['Banjarnegara', 'Blitar']}
# {'wanayasa': ['Purwakarta', 'Banjarnegara']}
# {'wapoga': ['Nabire', 'Waropen']}
# {'waru': ['Sidoarjo', 'Penajam Paser Utara', 'Pamekasan']}
# {'wates': ['Kediri', 'Blitar', 'Kulon Progo']}
# {'wawo': ['Kolaka Utara', 'Bima']}
# {'weru': ['Sukoharjo', 'Cirebon']}
# {'windesi': ['Kepulauan Yapen', 'Teluk Wondama']}
# {'wolo': ['Jayawijaya', 'Kolaka']}
# {'wonosalam': ['Demak', 'Jombang']}
# {'wonosari': ['Boalemo', 'Malang', 'Gunung Kidul', 'Klaten', 'Bondowoso']}
# {'wonosobo': ['Tanggamus', 'Wonosobo']}
# False

# %%
mp2p = Map(json.loads(open('province-to-province.json', 'r').read()).items())

# %%
mp2p.bj()
# Out:
# True

# %%
md2p = md2p.mapv(mp2p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 md2p = md2p.mapv(mp2p)
#
# Cell In[4], line 41, in Map.mapv(self, transform_or_dict)
#      39 for k, vs in self.data.items():
#      40     for v in vs:
# ---> 41         nvs = transform(v)
#      42         if not isinstance(nvs, list):
#      43             nvs = [nvs]
#
# Cell In[4], line 36, in Map.mapv.<locals>.<lambda>(k)
#      34 out = {}
#      35 if isinstance(transform_or_dict, dict) or isinstance(transform_or_dict, UserDict):
# ---> 36     transform = lambda k: transform_or_dict[k]
#      37 else:
#      38     transform = transform_or_dict
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:1058, in UserDict.__getitem__(self, key)
#    1056 if hasattr(self.__class__, "__missing__"):
#    1057     return self.__class__.__missing__(self, key)
# -> 1058 raise KeyError(key)
#
# KeyError: 'sumatera barat'

# %%
mp2p
# Out:
# {'Nusa Tenggara Barat (NTB)': ['nusa tenggara barat'], 'Sumatera Barat': ['sumatera barat'], 'DI Yogyakarta': ['di yogyakarta'], 'DKI Jakarta': ['dki jakarta'], 'Sumatera Selatan': ['sumatera selatan'], 'Kalimantan Tengah': ['kalimantan tengah'], 'Bengkulu': ['bengkulu'], 'Gorontalo': ['gorontalo'], 'Nusa Tenggara Timur (NTT)': ['nusa tenggara timur'], 'Maluku Utara': ['maluku utara'], 'Aceh (NAD)': ['nanggroe aceh darussalam'], 'Jawa Timur': ['jawa timur'], 'Lampung': ['lampung'], 'Jambi': ['jambi'], 'Banten': ['banten'], 'Bali': ['bali'], 'Kalimantan Timur': ['kalimantan timur'], 'Sulawesi Utara': ['sulawesi utara'], 'Sulawesi Selatan': ['sulawesi selatan'], 'Jawa Barat': ['jawa barat'], 'Sulawesi Tenggara': ['sulawesi tenggara'], 'Sulawesi Barat': ['sulawesi barat'], 'Maluku': ['maluku'], 'Sumatera Utara': ['sumatera utara'], 'Kepulauan Bangka Belitung': ['bangka belitung'], 'Kepulauan Riau': ['kepulauan riau'], 'Papua Barat': ['papua barat'], 'Jawa Tengah': ['jawa tengah'], 'Sulawesi Tengah': ['sulawesi tengah'], 'Riau': ['riau'], 'Kalimantan Barat': ['kalimantan barat'], 'Kalimantan Utara': ['kalimantan utara'], 'Kalimantan Selatan': ['kalimantan selatan'], 'Papua': ['papua']}

# %%
mc2p = mc2p.mapv(mp2p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 mc2p = mc2p.mapv(mp2p)
#
# Cell In[4], line 41, in Map.mapv(self, transform_or_dict)
#      39 for k, vs in self.data.items():
#      40     for v in vs:
# ---> 41         nvs = transform(v)
#      42         if not isinstance(nvs, list):
#      43             nvs = [nvs]
#
# Cell In[4], line 36, in Map.mapv.<locals>.<lambda>(k)
#      34 out = {}
#      35 if isinstance(transform_or_dict, dict) or isinstance(transform_or_dict, UserDict):
# ---> 36     transform = lambda k: transform_or_dict[k]
#      37 else:
#      38     transform = transform_or_dict
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/collections/__init__.py:1058, in UserDict.__getitem__(self, key)
#    1056 if hasattr(self.__class__, "__missing__"):
#    1057     return self.__class__.__missing__(self, key)
# -> 1058 raise KeyError(key)
#
# KeyError: 'di yogyakarta'

# %%
mp2p.reverse()
# Out:
# {'nusa tenggara barat': ['Nusa Tenggara Barat (NTB)'], 'sumatera barat': ['Sumatera Barat'], 'di yogyakarta': ['DI Yogyakarta'], 'dki jakarta': ['DKI Jakarta'], 'sumatera selatan': ['Sumatera Selatan'], 'kalimantan tengah': ['Kalimantan Tengah'], 'bengkulu': ['Bengkulu'], 'gorontalo': ['Gorontalo'], 'nusa tenggara timur': ['Nusa Tenggara Timur (NTT)'], 'maluku utara': ['Maluku Utara'], 'nanggroe aceh darussalam': ['Aceh (NAD)'], 'jawa timur': ['Jawa Timur'], 'lampung': ['Lampung'], 'jambi': ['Jambi'], 'banten': ['Banten'], 'bali': ['Bali'], 'kalimantan timur': ['Kalimantan Timur'], 'sulawesi utara': ['Sulawesi Utara'], 'sulawesi selatan': ['Sulawesi Selatan'], 'jawa barat': ['Jawa Barat'], 'sulawesi tenggara': ['Sulawesi Tenggara'], 'sulawesi barat': ['Sulawesi Barat'], 'maluku': ['Maluku'], 'sumatera utara': ['Sumatera Utara'], 'bangka belitung': ['Kepulauan Bangka Belitung'], 'kepulauan riau': ['Kepulauan Riau'], 'papua barat': ['Papua Barat'], 'jawa tengah': ['Jawa Tengah'], 'sulawesi tengah': ['Sulawesi Tengah'], 'riau': ['Riau'], 'kalimantan barat': ['Kalimantan Barat'], 'kalimantan utara': ['Kalimantan Utara'], 'kalimantan selatan': ['Kalimantan Selatan'], 'papua': ['Papua']}

# %%
synonyms = {
    "nusa tenggara barat": ["ntb"],
    "nusa tenggara timur": ["ntt"],
    "nanggroe aceh darussalam": ["aceh", "nad"],
    "dki jakarta": ["dki", "jakarta", "jakarta utara"],
    "di yogyakarta": ["daerah istimewa yogyakarta", "yogyakarta"],
    "jawa timur": ["east java"],
    "jawa barat": ["west java"],
    "sulawesi utara": ["sulut", "north sulawesi"],
    "sulawesi selatan": ["sulsel", "south sulawesi"],
    "sumatera utara": ["sumut", "north sumatera", "sumatra utara"],
    "sumatera barat": ["sumbar", "sumatra barat"],
    "sumatera selatan": ["sumsel", "south sumatera", "sumatra selatan"],
    "jawa tengah": ["jateng"],
    "jawa timur": ["jatim"],
    "kalimantan timur": ["kaltim"],
    "kalimantan tengah": ["kalteng"],
    "kepulauan riau": ["kepri"]
}

# %%
synonyms in mp2p.reverse()
# Out:
# True

# %%
mp2p.reverse() + synonyms
# Out:
# {'nusa tenggara barat': ['Nusa Tenggara Barat (NTB)', 'ntb'], 'nusa tenggara timur': ['ntt', 'Nusa Tenggara Timur (NTT)'], 'nanggroe aceh darussalam': ['aceh', 'Aceh (NAD)', 'nad'], 'dki jakarta': ['dki', 'DKI Jakarta', 'jakarta', 'jakarta utara'], 'di yogyakarta': ['DI Yogyakarta', 'yogyakarta', 'daerah istimewa yogyakarta'], 'jawa timur': ['jatim', 'Jawa Timur'], 'jawa barat': ['Jawa Barat', 'west java'], 'sulawesi utara': ['north sulawesi', 'Sulawesi Utara', 'sulut'], 'sulawesi selatan': ['south sulawesi', 'sulsel', 'Sulawesi Selatan'], 'sumatera utara': ['north sumatera', 'sumatra utara', 'Sumatera Utara', 'sumut'], 'sumatera barat': ['sumatra barat', 'Sumatera Barat', 'sumbar'], 'sumatera selatan': ['sumatra selatan', 'sumsel', 'south sumatera', 'Sumatera Selatan'], 'jawa tengah': ['Jawa Tengah', 'jateng'], 'kalimantan timur': ['Kalimantan Timur', 'kaltim'], 'kalimantan tengah': ['kalteng', 'Kalimantan Tengah'], 'kepulauan riau': ['kepri', 'Kepulauan Riau'], 'bengkulu': ['Bengkulu'], 'gorontalo': ['Gorontalo'], 'maluku utara': ['Maluku Utara'], 'lampung': ['Lampung'], 'jambi': ['Jambi'], 'banten': ['Banten'], 'bali': ['Bali'], 'sulawesi tenggara': ['Sulawesi Tenggara'], 'sulawesi barat': ['Sulawesi Barat'], 'maluku': ['Maluku'], 'bangka belitung': ['Kepulauan Bangka Belitung'], 'papua barat': ['Papua Barat'], 'sulawesi tengah': ['Sulawesi Tengah'], 'riau': ['Riau'], 'kalimantan barat': ['Kalimantan Barat'], 'kalimantan utara': ['Kalimantan Utara'], 'kalimantan selatan': ['Kalimantan Selatan'], 'papua': ['Papua']}

# %%
mp2p = (mp2p.reverse() + synonyms).mapv(gtransform).reverse()

# %%
mp2p
# Out:
# {'ntb': ['nusa tenggara barat'], 'nusatenggarabarat': ['nusa tenggara barat'], 'ntt': ['nusa tenggara timur'], 'nusatenggaratimur': ['nusa tenggara timur'], 'aceh': ['nanggroe aceh darussalam'], 'nad': ['nanggroe aceh darussalam'], 'dki': ['dki jakarta'], 'jakartautara': ['dki jakarta'], 'dkijakarta': ['dki jakarta'], 'jakarta': ['dki jakarta'], 'yogyakarta': ['di yogyakarta'], 'daerahistimewayogyakarta': ['di yogyakarta'], 'diyogyakarta': ['di yogyakarta'], 'jawatimur': ['jawa timur'], 'jatim': ['jawa timur'], 'westjava': ['jawa barat'], 'jawabarat': ['jawa barat'], 'northsulawesi': ['sulawesi utara'], 'sulut': ['sulawesi utara'], 'sulawesiutara': ['sulawesi utara'], 'southsulawesi': ['sulawesi selatan'], 'sulsel': ['sulawesi selatan'], 'sulawesiselatan': ['sulawesi selatan'], 'northsumatera': ['sumatera utara'], 'sumatrautara': ['sumatera utara'], 'sumaterautara': ['sumatera utara'], 'sumut': ['sumatera utara'], 'sumaterabarat': ['sumatera barat'], 'sumbar': ['sumatera barat'], 'sumatrabarat': ['sumatera barat'], 'sumatraselatan': ['sumatera selatan'], 'sumsel': ['sumatera selatan'], 'sumateraselatan': ['sumatera selatan'], 'southsumatera': ['sumatera selatan'], 'jateng': ['jawa tengah'], 'jawatengah': ['jawa tengah'], 'kaltim': ['kalimantan timur'], 'kalimantantimur': ['kalimantan timur'], 'kalteng': ['kalimantan tengah'], 'kalimantantengah': ['kalimantan tengah'], 'kepri': ['kepulauan riau'], 'kepulauanriau': ['kepulauan riau'], 'bengkulu': ['bengkulu'], 'gorontalo': ['gorontalo'], 'malukuutara': ['maluku utara'], 'lampung': ['lampung'], 'jambi': ['jambi'], 'banten': ['banten'], 'bali': ['bali'], 'sulawesitenggara': ['sulawesi tenggara'], 'sulawesibarat': ['sulawesi barat'], 'maluku': ['maluku'], 'kepulauanbangkabelitung': ['bangka belitung'], 'papuabarat': ['papua barat'], 'sulawesitengah': ['sulawesi tengah'], 'riau': ['riau'], 'kalimantanbarat': ['kalimantan barat'], 'kalimantanutara': ['kalimantan utara'], 'kalimantanselatan': ['kalimantan selatan'], 'papua': ['papua']}

# %%
mc2p
# Out:
# {'yogyakarta': ['di yogyakarta'], 'yalimo': ['papua'], 'yahukimo': ['papua'], 'wonosobo': ['jawa tengah'], 'wonogiri': ['jawa tengah'], 'waykanan': ['lampung'], 'waropen': ['papua'], 'wakatobi': ['sulawesi tenggara'], 'wajo': ['sulawesi selatan'], 'tulungagung': ['jawa timur'], 'tulangbawangbarat': ['lampung'], 'tulangbawang': ['lampung'], 'tuban': ['jawa timur'], 'tual': ['maluku'], 'trenggalek': ['jawa timur'], 'torajautara': ['sulawesi selatan'], 'tomohon': ['sulawesi utara'], 'tolikara': ['papua'], 'tolitoli': ['sulawesi tengah'], 'tojounauna': ['sulawesi tengah'], 'tobasamosir': ['sumatera utara'], 'timortengahutara': ['nusa tenggara timur'], 'timortengahselatan': ['nusa tenggara timur'], 'tidorekepulauan': ['maluku utara'], 'ternate': ['maluku utara'], 'temanggung': ['jawa tengah'], 'telukwondama': ['papua barat'], 'telukbintuni': ['papua barat'], 'tegal': ['jawa tengah'], 'tebo': ['jambi'], 'tebingtinggi': ['sumatera utara'], 'tasikmalaya': ['jawa barat'], 'tarakan': ['kalimantan utara'], 'tapin': ['kalimantan selatan'], 'tapanuliutara': ['sumatera utara'], 'tapanulitengah': ['sumatera utara'], 'tapanuliselatan': ['sumatera utara'], 'tanjungpinang': ['kepulauan riau'], 'tanjungjabungtimur': ['jambi'], 'tanjungjabungbarat': ['jambi'], 'tanjungbalai': ['sumatera utara'], 'tanggamus': ['lampung'], 'tangerangselatan': ['banten'], 'tangerang': ['banten'], 'tanahlaut': ['kal
luru': ['sumatera barat'], 'akat': ['papua'], 'alak': ['nusa tenggara timur'], 'alalak': ['kalimantan selatan'], 'alambarajo': ['jambi'], 'alama': ['papua'], 'alangalanglebar': ['sumatera selatan'], 'alapan': ['nanggroe aceh darussalam'], 'alafan': ['nanggroe aceh darussalam'], 'alas': ['nusa tenggara barat'], 'alasbarat': ['nusa tenggara barat'], 'alasa': ['sumatera utara'], 'alasatalumuzoi': ['sumatera utara'], 'alemsom': ['papua'], 'alian': ['jawa tengah'], 'aliyan': ['jawa tengah'], 'alla': ['sulawesi selatan'], 'alok': ['nusa tenggara timur'], 'alokbarat': ['nusa tenggara timur'], 'aloktimur': ['nusa tenggara timur'], 'alorbaratdaya': ['nusa tenggara timur'], 'alorbaratlaut': ['nusa tenggara timur'], 'alorselatan': ['nusa tenggara timur'], 'alortengahutara': ['nusa tenggara timur'], 'alortimur': ['nusa tenggara timur'], 'alortimurlaut': ['nusa tenggara timur'], 'alu': ['sulawesi barat'], 'allu': ['sulawesi barat'], 'aluhaluh': ['jawa barat'], 'amabioefeto': ['nusa tenggara timur'], 'amabioefetotimur': ['nusa tenggara timur'], 'amahai': ['maluku'], 'amalatu': ['maluku'], 'amali': ['sulawesi selatan'], 'amanatunselatan': ['n ...

# %%
op2p = Map(json.loads(open('province-to-province.json', 'r').read()).items())

# %%
op2p.bj()
# Out:
# True

# %%
mi2p = Map({idx: v for idx, v in enumerate(op2p.values())})
mi2p
# Out:
# {0: ['nusa tenggara barat'], 1: ['sumatera barat'], 2: ['di yogyakarta'], 3: ['dki jakarta'], 4: ['sumatera selatan'], 5: ['kalimantan tengah'], 6: ['bengkulu'], 7: ['gorontalo'], 8: ['nusa tenggara timur'], 9: ['maluku utara'], 10: ['nanggroe aceh darussalam'], 11: ['jawa timur'], 12: ['lampung'], 13: ['jambi'], 14: ['banten'], 15: ['bali'], 16: ['kalimantan timur'], 17: ['sulawesi utara'], 18: ['sulawesi selatan'], 19: ['jawa barat'], 20: ['sulawesi tenggara'], 21: ['sulawesi barat'], 22: ['maluku'], 23: ['sumatera utara'], 24: ['bangka belitung'], 25: ['kepulauan riau'], 26: ['papua barat'], 27: ['jawa tengah'], 28: ['sulawesi tengah'], 29: ['riau'], 30: ['kalimantan barat'], 31: ['kalimantan utara'], 32: ['kalimantan selatan'], 33: ['papua']}

# %%
mp2i = mp2p.mapv(mi2p.reverse())

# %%
mc2i = mc2p.mapv(mi2p.reverse())

# %%
md2i = md2p.mapv(mi2p.reverse())

# %%
open('out/mp2i.json', 'w').write(mp2i.json())
# Out:
# 1186

# %%
open('out/mc2i.json', 'w').write(mc2i.json())
# Out:
# 10523

# %%
open('out/md2i.json', 'w').write(md2i.json())
# Out:
# 136342

# %%
open('out/mi2p.json', 'w').write(mi2p.json())
# Out:
# 824

# %%
md2p.bj()
# Out:
# {'airhitam': ['jambi', 'lampung']}
# {'ambalau': ['kalimantan barat', 'maluku']}
# {'ambarawa': ['jawa tengah', 'lampung']}
# {'ampelgading': ['jawa tengah', 'jawa timur']}
# {'angsana': ['kalimantan selatan', 'banten']}
# {'badau': ['bangka belitung', 'kalimantan barat']}
# {'bandar': ['jawa tengah', 'sumatera utara', 'jawa timur', 'nanggroe aceh darussalam']}
# {'bandung': ['jawa timur', 'banten']}
# {'bangko': ['jambi', 'riau']}
# {'bangunpurba': ['sumatera utara', 'riau']}
# {'banjar': ['jawa barat', 'bali', 'banten']}
# {'banjarsari': ['jawa tengah', 'jawa barat', 'banten']}
# {'banyumas': ['jawa tengah', 'lampung']}
# {'banyuputih': ['jawa tengah', 'jawa timur']}
# {'baros': ['jawa barat', 'banten']}
# {'batang': ['jawa tengah', 'sulawesi selatan']}
# {'batuampar': ['kalimantan selatan', 'kepulauan riau', 'kalimantan barat', 'kalimantan tengah', 'kalimantan timur']}
# {'batuputih': ['lampung', 'sulawesi tenggara', 'nusa tenggara timur', 'jawa timur', 'kalimantan timur']}
# {'bayan': ['jawa tengah', 'nusa tenggara barat']}
# {'beji': ['jawa barat', 'jawa timur']}
# {'belimbing': ['kalimantan barat', 'sumatera selatan']}
# {'belitang': ['kalimantan barat', 'sumatera selatan']}
# {'biau': ['gorontalo', 'sulawesi tengah']}
# {'binangun': ['jawa tengah', 'jawa timur']}
# {'binuang': ['kalimantan selatan', 'sulawesi barat', 'banten']}
# {'bojong': ['jawa tengah', 'jawa barat', 'banten']}
# {'bojongsari': ['jawa tengah', 'jawa barat']}
# {'bola': ['nusa tenggara timur', 'sulawesi selatan']}
# {'bone': ['sulawesi tenggara', 'gorontalo']}
# {'bringin': ['jawa tengah', 'jawa timur']}
# {'bukitbatu': ['riau', 'kalimantan tengah']}
# {'bukitraya': ['riau', 'kalimantan tengah']}
# {'bungamayang': ['lampung', 'sumatera selatan']}
# {'candipuro': ['lampung', 'jawa timur']}
# {'cempaka': ['kalimantan selatan', 'sumatera selatan']}
# {'cibadak': ['jawa barat', 'banten']}
# {'cibeber': ['jawa barat', 'banten']}
# {'cibitung': ['jawa barat', 'banten']}
# {'ciledug': ['jawa barat', 'banten']}
# {'cimanggu': ['jawa tengah', 'jawa barat', 'banten']}
# {'ciomas': ['jawa barat', 'banten']}
# {'cipanas': ['jawa barat', 'banten']}
# {'cipayung': ['jawa barat', 'dki jakarta']}
# {'dendang': ['jambi', 'bangka belitung']}
# {'depok': ['jawa barat', 'di yogyakarta']}
# {'donorojo': ['jawa tengah', 'jawa timur']}
# {'dukun': ['jawa tengah', 'jawa timur']}
# {'gadingrejo': ['lampung', 'jawa timur']}
# {'galang': ['sumatera utara', 'kepulauan riau', 'sulawesi tengah']}
# {'gebang': ['jawa tengah', 'jawa barat', 'sumatera utara']}
# {'gempol': ['jawa barat', 'jawa timur']}
# {'gondang': ['jawa tengah', 'jawa timur']}
# {'grogol': ['jawa tengah', 'jawa timur']}
# {'gunungmeriah': ['sumatera utara', 'nanggroe aceh darussalam']}
# {'gunungsari': ['nusa tenggara barat', 'banten']}
# {'jabung': ['lampung', 'jawa timur']}
# {'jatibarang': ['jawa tengah', 'jawa barat']}
# {'jatinegara': ['jawa tengah', 'dki jakarta']}
# {'jatiroto': ['jawa tengah', 'jawa timur']}
# {'jetis': ['di yogyakarta', 'jawa timur']}
# {'jombang': ['jawa timur', 'banten']}
# {'kalibawang': ['jawa tengah', 'di yogyakarta']}
# {'kalumpang': ['kalimantan selatan', 'sulawesi barat']}
# {'kandangan': ['jawa tengah', 'kalimantan selatan', 'jawa timur']}
# {'kandis': ['riau', 'sumatera selatan']}
# {'karangjaya': ['jawa barat', 'sumatera selatan']}
# {'karangtengah': ['jawa tengah', 'jawa barat', 'banten']}
# {'karangan': ['jawa timur', 'kalimantan timur']}
# {'karanganyar': ['jawa tengah', 'jawa timur']}
# {'karas': ['papua barat', 'jawa timur']}
# {'kayanhilir': ['kalimantan utara', 'kalimantan barat']}
# {'kayanhulu': ['kalimantan utara', 'kalimantan barat']}
# {'kebonagung': ['jawa tengah', 'jawa timur']}
# {'kedawung': ['jawa tengah', 'jawa barat']}
# {'kediri': ['nusa tenggara barat', 'bali']}
# {'kemiri': ['jawa tengah', 'banten']}
# {'kemuning': ['riau', 'sumatera selatan']}
# {'kendal': ['jawa tengah', 'jawa timur']}
# {'ketapang': ['lampung', 'jawa timur']}
# {'konda': ['sulawesi tenggara', 'papua barat', 'papua']}
# {'kotaagung': ['lampung', 'sumatera selatan']}
# {'kotabaru': ['jambi', 'nusa tenggara timur', 'jawa barat']}
# {'kotobaru': ['jambi', 'sumatera barat']}
# {'kranggan': ['jawa tengah', 'jawa timur']}
# {'kraton': ['di yogyakarta', 'jawa timur']}
# {'kroya': ['jawa tengah', 'jawa barat']}
# {'kuala': ['sumatera utara', 'nanggroe aceh darussalam']}
# {'kubu': ['kalimantan barat', 'bali', 'papua', 'riau']}
# {'kuranji': ['sumatera barat', 'kalimantan selatan']}
# {'kuripan': ['nusa tenggara barat', 'kalimantan selatan', 'jawa timur']}
# {'labuan': ['banten', 'sulawesi tengah']}
# {'labuhanhaji': ['nusa tenggara barat', 'nanggroe aceh darussalam']}
# {'lais': ['bengkulu', 'sumatera selatan']}
# {'larangan': ['jawa tengah', 'jawa timur', 'banten']}
# {'lebakwangi': ['jawa barat', 'banten']}
# {'lembang': ['jawa barat', 'sulawesi selatan']}
# {'lembo': ['sulawesi tenggara', 'sulawesi tengah']}
# {'lengkong': ['jawa barat', 'jawa timur']}
# {'limapuluh': ['sumatera utara', 'riau']}
# {'losari': ['jawa tengah', 'jawa barat']}
# {'maja': ['jawa barat', 'banten']}
# {'mare': ['papua barat', 'sulawesi selatan']}
# {'martapura': ['jawa barat', 'sumatera selatan']}
# {'meranti': ['kalimantan barat', 'sumatera utara']}
# {'mesuji': ['lampung', 'sumatera selatan']}
# {'muara': ['sumatera utara', 'papua']}
# {'muaradua': ['sumatera selatan', 'nanggroe aceh darussalam']}
# {'ngadirojo': ['jawa tengah', 'jawa timur']}
# {'ngawen': ['jawa tengah', 'di yogyakarta']}
# {'ngemplak': ['jawa tengah', 'di yogyakarta']}
# {'nguntoronadi': ['jawa tengah', 'jawa timur']}
# {'pabuaran': ['jawa barat', 'banten']}
# {'pacet': ['jawa barat', 'jawa timur']}
# {'pagelaran': ['lampung', 'jawa barat', 'jawa timur', 'banten']}
# {'pakem': ['di yogyakarta', 'jawa timur']}
# {'pakis': ['jawa tengah', 'jawa timur']}
# {'pakisaji': ['jawa tengah', 'jawa timur']}
# {'palangga': ['sulawesi tenggara', 'sulawesi selatan']}
# {'pantaicermin': ['sumatera barat', 'sumatera utara']}
# {'panti': ['sumatera barat', 'jawa timur']}
# {'parigi': ['sulawesi tenggara', 'jawa barat', 'sulawesi selatan', 'sulawesi tengah']}
# {'pasirputih': ['sulawesi tenggara', 'papua']}
# {'pauh': ['jambi', 'sumatera barat']}
# {'payung': ['bangka belitung', 'sumatera utara']}
# {'payungsekaki': ['sumatera barat', 'riau']}
# {'prambanan': ['jawa tengah', 'di yogyakarta']}
# {'pulaulaut': ['kalimantan selatan', 'kepulauan riau']}
# {'pulausembilan': ['kalimantan selatan', 'sulawesi selatan']}
# {'pulautiga': ['papua', 'kepulauan riau']}
# {'pulosari': ['jawa tengah', 'banten']}
# {'purwakarta': ['jawa barat', 'banten']}
# {'purwodadi': ['jawa tengah', 'jawa timur', 'sumatera selatan']}
# {'purworejo': ['jawa tengah', 'jawa timur']}
# {'purwosari': ['di yogyakarta', 'jawa timur']}
# {'rambutan': ['sumatera utara', 'sumatera selatan']}
# {'rembang': ['jawa tengah', 'jawa timur']}
# {'rumbia': ['lampung', 'sulawesi tenggara', 'sulawesi selatan']}
# {'sampang': ['jawa tengah', 'jawa timur']}
# {'sawangan': ['jawa tengah', 'jawa barat']}
# {'sei': ['kalimantan barat', 'jawa barat', 'sumatera utara', 'kepulauan riau']}
# {'sungaipinang': ['jawa barat', 'sumatera selatan', 'kalimantan timur']}
# {'selat': ['bali', 'kalimantan tengah']}
# {'sendana': ['sulawesi selatan', 'sulawesi barat']}
# {'serbajadi': ['sumatera utara', 'nanggroe aceh darussalam']}
# {'setu': ['jawa barat', 'banten']}
# {'siantan': ['kalimantan barat', 'kepulauan riau']}
# {'sidorejo': ['jawa tengah', 'jawa timur']}
# {'simpangempat': ['jawa barat', 'sumatera utara', 'kalimantan selatan']}
# {'simpangkanan': ['riau', 'nanggroe aceh darussalam']}
# {'singkil': ['nanggroe aceh darussalam', 'sulawesi utara']}
# {'soreang': ['jawa barat', 'sulawesi selatan']}
# {'sragi': ['jawa tengah', 'lampung']}
# {'subah': ['jawa tengah', 'kalimantan barat']}
# {'sukakarya': ['jawa barat', 'sumatera selatan', 'nanggroe aceh darussalam']}
# {'sukabumi': ['lampung', 'jawa barat']}
# {'sukadana': ['lampung', 'jawa barat', 'kalimantan barat']}
# {'sukajadi': ['jawa barat', 'riau']}
# {'sukajaya': ['jawa barat', 'nanggroe aceh darussalam']}
# {'sukamakmur': ['jawa barat', 'nanggroe aceh darussalam']}
# {'sukaraja': ['jawa barat', 'bengkulu']}
# {'sukarame': ['lampung', 'jawa barat']}
# {'sukaresmi': ['jawa barat', 'banten']}
# {'sukodono': ['jawa tengah', 'jawa timur']}
# {'sukoharjo': ['jawa tengah', 'lampung']}
# {'sukolilo': ['jawa tengah', 'jawa timur']}
# {'sukorejo': ['jawa tengah', 'jawa timur']}
# {'sumber': ['jawa tengah', 'jawa barat', 'jawa timur']}
# {'sumberjaya': ['lampung', 'jawa barat']}
# {'sumberejo': ['lampung', 'jawa timur']}
# {'sungairaya': ['kalimantan barat', 'kalimantan selatan', 'nanggroe aceh darussalam']}
# {'sungairumbai': ['sumatera barat', 'bengkulu']}
# {'suruh': ['jawa tengah', 'jawa timur']}
# {'susukan': ['jawa tengah', 'jawa barat']}
# {'tabang': ['sulawesi barat', 'kalimantan timur']}
# {'talangpadang': ['lampung', 'sumatera selatan']}
# {'talawi': ['sumatera barat', 'sumatera utara']}
# {'talun': ['jawa tengah', 'jawa barat', 'jawa timur']}
# {'taman': ['jawa tengah', 'jawa timur']}
# {'tamansari': ['jawa tengah', 'bangka belitung', 'jawa barat', 'dki jakarta']}
# {'tambak': ['jawa tengah', 'jawa timur']}
# {'tambaksari': ['jawa barat', 'jawa timur']}
# {'tambora': ['nusa tenggara barat', 'dki jakarta']}
# {'tanahabang': ['sumatera selatan', 'dki jakarta']}
# {'tanahmerah': ['jawa timur', 'riau']}
# {'tanjung': ['jawa tengah', 'nusa tenggara barat', 'kalimantan selatan']}
# {'tanjungharapan': ['sumatera barat', 'kalimantan timur']}
# {'tanjungraja': ['lampung', 'sumatera selatan']}
# {'tanjungraya': ['lampung', 'sumatera barat']}
# {'tanjungsari': ['lampung', 'jawa barat', 'di yogyakarta']}
# {'tebingtinggi': ['kalimantan selatan', 'sumatera utara', 'riau', 'sumatera selatan', 'jambi']}
# {'tegalrejo': ['jawa tengah', 'di yogyakarta']}
# {'telukdalam': ['sumatera utara', 'nanggroe aceh darussalam']}
# {'telukpandan': ['lampung', 'kalimantan timur']}
# {'tempuran': ['jawa tengah', 'jawa barat']}
# {'tikala': ['sulawesi selatan', 'sulawesi utara']}
# {'tomini': ['sulawesi tengah', 'sulawesi utara']}
# {'trucuk': ['jawa tengah', 'jawa timur']}
# {'tugu': ['jawa tengah', 'jawa timur']}
# {'tungkalilir': ['jambi', 'sumatera selatan']}
# {'turi': ['di yogyakarta', 'jawa timur']}
# {'ujanmas': ['bengkulu', 'sumatera selatan']}
# {'ujungbatu': ['sumatera utara', 'riau']}
# {'wonodadi': ['jawa tengah', 'jawa timur']}
# {'wanayasa': ['jawa tengah', 'jawa barat']}
# {'waru': ['jawa timur', 'kalimantan timur']}
# {'wates': ['di yogyakarta', 'jawa timur']}
# {'wawo': ['sulawesi tenggara', 'nusa tenggara barat']}
# {'weru': ['jawa tengah', 'jawa barat']}
# {'windesi': ['papua barat', 'papua']}
# {'wolo': ['sulawesi tenggara', 'papua']}
# {'wonosalam': ['jawa tengah', 'jawa timur']}
# {'wonosari': ['jawa tengah', 'di yogyakarta', 'jawa timur', 'gorontalo']}
# {'wonosobo': ['jawa tengah', 'lampung']}
# False
